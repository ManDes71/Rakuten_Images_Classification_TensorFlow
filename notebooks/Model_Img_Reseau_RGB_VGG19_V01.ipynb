# %%
import numpy as np
import pandas as pd
from joblib import dump
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix # Pour les performances de classification
from imblearn.under_sampling import RandomUnderSampler
from keras.optimizers import SGD,Adam
from datetime import datetime
maintenant = datetime.now()
print(maintenant)
import tensorflow as tf

# activation GPU

gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)




from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Dense # Pour construire un réseau de neurones et
                                                 # instancier une couche d'entrée et une couche den
from sklearn.ensemble import RandomForestClassifier # Pour instancier et entraîner un modèle Random Forest
import matplotlib.pyplot as plt
import os
#import cv2
import gc
import itertools # Pour créer des itérateurs
import pickle
# Out:
# 2024-05-25 22:54:50.327895
# 1 Physical GPUs, 1 Logical GPUs

# %%
VERSION = "_V01"
SUFFIXE_FICHIER = "VGG19" + VERSION
STRATEGIE = "sampling_strategy_B1" + VERSION +".csv" # effectifs par classe retenu après over et under sampling
IMGSIZE       = 400    # Taille de l'image en input
EPOCH         = 40     # nombre d'epoch 
BATCH_SIZE    = 16     # traitement par batch d'images avant la descente de gradient
FREEZE_LAYERS = 17     # pour un EfficientNetB1 freeze de réapprentissage de certaines couches (22 couches au total)
NB_PAR_LABEL_MAX = 5000 # nombre maximun d'enregistrement par label = undersampling
NB_PAR_LABEL_MIN = 2000 # nombre maximun d'enregistrement par label = oversampling
TRAIN         = True   # Entrainement ou utilisation d'un réseau déjà entrainé

# %%
import sys
sys.path.append('../src')
import Bibli_DataScience_3_2 as ds
import CNN_DataScience_2 as cnn
# Out:
# section :  ['DOSSIER', 'FICHIER']

# %%
# Pour recharger si nesséssaire
import imp
imp.reload(ds)
imp.reload(cnn)
# Out:
# section :  ['DOSSIER', 'FICHIER']
# <module 'CNN_DataScience_2' from 'E:\\Manuel\\PROJET\\Rakuten_Images_Classification_TensorFlow\\notebooks\\../src\\CNN_DataScience_2.py'>

# %%
# lecture des données sources d'entrainement
df_feats=pd.read_csv(ds.get_RACINE_DOSSIER() + 'X_train_update.csv')

# lecture des données cibles d'entrainement
df_target=pd.read_csv(ds.get_RACINE_DOSSIER() + 'Y_train_CVw08PX.csv')


# création d'un dataframe globale -  jointure
df=df_feats.merge(df_target,on='Unnamed: 0',how='inner')
df.rename(columns={'Unnamed: 0': 'Id'}, inplace=True)
#cat=df_target['prdtypecode'].sort_values().unique()
nomenclature=pd.read_csv(ds.get_RACINE_DOSSIER() + 'NOMENCLATURE.csv',header=0,encoding='utf-8',sep=';',index_col=0)
catdict=nomenclature.to_dict()['definition']
Lcat=df_target.sort_values(by = ['prdtypecode'])['prdtypecode'].unique()
Lcat
# Out:
# array([  10,   40,   50,   60, 1140, 1160, 1180, 1280, 1281, 1300, 1301,
#        1302, 1320, 1560, 1920, 1940, 2060, 2220, 2280, 2403, 2462, 2522,
#        2582, 2583, 2585, 2705, 2905], dtype=int64)

# %%
df['nom_image']=df.apply(lambda row: "image_" +  str(row['imageid']) 
                                     + "_product_" + str(row['productid']) + ".jpg",axis=1)
print("Nb enreg ", str(df.shape[0]))
df_img=df.copy()
# Out:
# Nb enreg  84916

# %%
folder_path = ds.get_RACINE_IMAGES() 
df['filepath']=df['nom_image'].apply(lambda x : os.path.join(folder_path, x))

# %% [markdown]
# ## test de lecture d'image¶

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# Chemin de l'image
filename = df.nom_image[0]
filepath = os.path.join(folder_path, filename)
# Lecture du fichier
im = tf.io.read_file(filepath)

# On décode le fichier
im = tf.image.decode_jpeg(im, channels=3)

print("Taille de l'image :", im.shape)

# Affichage du tensor
plt.imshow(im);
# Out:
# Taille de l'image : (500, 500, 3)

# %% [markdown]
# ### REDIMENSIONNEMENT
# Pour avoir un temps d'entrainement du modèle raisonnable,
# il est nécessaire de redimensionner les images.
# **A l'origine les images ont une taille de 500*500 pixels.**

# %%
filepath = df.filepath[0]
# Lecture du fichier
im = tf.io.read_file(filepath)
# On décode le fichier
im = tf.image.decode_jpeg(im, channels=3)
# Redimensionnement
tf.image.resize(im, size=(IMGSIZE,IMGSIZE))
# Out:
# <tf.Tensor: shape=(400, 400, 3), dtype=float32, numpy=
# array([[[254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.]],
#
#        [[254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.]],
#
#        [[254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.]],
#
#        ...,
#
#        [[254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.]],
#
#        [[254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.]],
#
#        [[254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.]]], dtype=float32)>

# %%
from sklearn.model_selection import train_test_split

import numpy as np

X = df.drop('prdtypecode', axis=1)
y = df['prdtypecode'] 

X_train_avant, X_test_avant, y_train_avant, y_test_avant = train_test_split(X, y, train_size=0.8, random_state=1234,
                                                              stratify=y,shuffle=True)

# %%
X_train = np.array(X_train_avant['filepath'])
print(X_train.shape)
X_test = np.array(X_test_avant['filepath'])
y_train = np.array(y_train_avant)
print(X_test.shape)
y_test = np.array(y_test_avant )
X_train=X_train.reshape(-1,1)
y_train=y_train.reshape(-1,1)
X_test=X_test.reshape(-1,1)
y_test=y_test.reshape(-1,1)
# Out:
# (67932,)
# (16984,)

# %% [markdown]
# ### Evaluation de la répartition des catégories

# %%
y_serie =pd.Series(y_train.reshape(-1,)).value_counts()
majority_class = y_serie.index[0]
print(majority_class)
y_serie
# Out:
# 2583
# 2583    8167
# 1560    4058
# 1300    4036
# 2060    3994
# 2522    3991
# 1280    3896
# 2403    3819
# 2280    3808
# 1920    3442
# 1160    3162
# 1320    2593
# 10      2493
# 2705    2209
# 1140    2137
# 2582    2071
# 40      2006
# 2585    1997
# 1302    1993
# 1281    1656
# 50      1345
# 2462    1137
# 2905     698
# 60       666
# 2220     659
# 1301     646
# 1940     642
# 1180     611
# Name: count, dtype: int64

# %% [markdown]
# ### UNDERSAMPLING
# On effectue un undersampling définit par le paramètre : NB_PAR_LABEL_MAX (cf debut de programme)
# Ici **undersampling à 5000**

# %%
new_class_counts = y_serie.copy()
sampling_strategy=new_class_counts.to_dict()
for key in sampling_strategy:
  if sampling_strategy[key] > NB_PAR_LABEL_MAX:
    sampling_strategy[key] = NB_PAR_LABEL_MAX
del y_serie,new_class_counts
#print(type(sampling_strategy))
spstrag=pd.DataFrame.from_dict(sampling_strategy,orient='index').rename(columns={0:'Qunatity'})
spstrag.to_csv(ds.get_RACINE_SAUVEGARDE()+STRATEGIE)
print("Stategie de sampling")
sampling_strategy
# Out:
# Stategie de sampling
# {2583: 5000,
#  1560: 4058,
#  1300: 4036,
#  2060: 3994,
#  2522: 3991,
#  1280: 3896,
#  2403: 3819,
#  2280: 3808,
#  1920: 3442,
#  1160: 3162,
#  1320: 2593,
#  10: 2493,
#  2705: 2209,
#  1140: 2137,
#  2582: 2071,
#  40: 2006,
#  2585: 1997,
#  1302: 1993,
#  1281: 1656,
#  50: 1345,
#  2462: 1137,
#  2905: 698,
#  60: 666,
#  2220: 659,
#  1301: 646,
#  1940: 642,
#  1180: 611}

# %%
rUs = RandomUnderSampler(sampling_strategy=sampling_strategy)
X_ru, y_ru = rUs.fit_resample(X_train, y_train  )
#del   X_Reshape, y
#gc.collect()
print(len(X_ru))
print(len(X_ru))
# Out:
# 64765
# 64765

# %% [markdown]
# ##### Après la répartition entre le jeu de test et le jeu d'entrainement
# **la classe la plus représentée** du jeu d'entrainement comporte **5000 occurences**

# %%
y_serie =pd.Series(y_ru).value_counts()
majority_class = y_serie.index[0]
print(majority_class)
y_serie
# Out:
# 2583
# 2583    5000
# 1560    4058
# 1300    4036
# 2060    3994
# 2522    3991
# 1280    3896
# 2403    3819
# 2280    3808
# 1920    3442
# 1160    3162
# 1320    2593
# 10      2493
# 2705    2209
# 1140    2137
# 2582    2071
# 40      2006
# 2585    1997
# 1302    1993
# 1281    1656
# 50      1345
# 2462    1137
# 2905     698
# 60       666
# 2220     659
# 1301     646
# 1940     642
# 1180     611
# Name: count, dtype: int64

# %% [markdown]
# ### OVERSAMPLING
# On effectue un oversampling définit par le paramètre : B_PAR_LABEL_MIN (cf debut de programme)
# On utilisera par la suite un génarateur d'images pour générer des images différentes de chaque enregistrement
# **ici oversampling à 2000.**

# %%
new_class_counts = y_serie.copy()
sampling_strategy=new_class_counts.to_dict()
for key in sampling_strategy:
  if sampling_strategy[key] <NB_PAR_LABEL_MIN :
  #if key in [1180,2220]:  
    sampling_strategy[key] = NB_PAR_LABEL_MIN
spstrag=pd.DataFrame.from_dict(sampling_strategy,orient='index').rename(columns={0:'Qunatity'})
spstrag.to_csv(ds.get_RACINE_SAUVEGARDE()+STRATEGIE)  
print("Stategie de sampling")
sampling_strategy
# Out:
# Stategie de sampling
# {2583: 5000,
#  1560: 4058,
#  1300: 4036,
#  2060: 3994,
#  2522: 3991,
#  1280: 3896,
#  2403: 3819,
#  2280: 3808,
#  1920: 3442,
#  1160: 3162,
#  1320: 2593,
#  10: 2493,
#  2705: 2209,
#  1140: 2137,
#  2582: 2071,
#  40: 2006,
#  2585: 2000,
#  1302: 2000,
#  1281: 2000,
#  50: 2000,
#  2462: 2000,
#  2905: 2000,
#  60: 2000,
#  2220: 2000,
#  1301: 2000,
#  1940: 2000,
#  1180: 2000}

# %%
from imblearn.over_sampling import RandomOverSampler
rOs = RandomOverSampler(sampling_strategy=sampling_strategy)
#rOs = RandomOverSampler(sampling_strategy=sampling_strategy,random_state=1234,shrinkage=1)
X_train_path, y_train = rOs.fit_resample(X_ru, y_ru)
X_train_path, y_train = shuffle(X_train_path, y_train, random_state=42)

# %%
y_res_series = pd.Series(y_train).value_counts()
print(y_res_series)
# Out:
# 2583    5000
# 1560    4058
# 1300    4036
# 2060    3994
# 2522    3991
# 1280    3896
# 2403    3819
# 2280    3808
# 1920    3442
# 1160    3162
# 1320    2593
# 10      2493
# 2705    2209
# 1140    2137
# 2582    2071
# 40      2006
# 1302    2000
# 50      2000
# 2585    2000
# 1301    2000
# 2905    2000
# 1180    2000
# 2462    2000
# 1281    2000
# 60      2000
# 2220    2000
# 1940    2000
# Name: count, dtype: int64

# %%
print(y_train.shape)
print(y_test.shape)
print(y_test)
y_test=y_test.ravel()
print(y_test)
# Out:
# (74715,)
# (16984, 1)
# [[1301]
#  [1140]
#  [2583]
#  ...
#  [2583]
#  [2583]
#  [1180]]
# [1301 1140 2583 ... 2583 2583 1180]

# %%
X_train_path=X_train_path.reshape(-1,)
print(X_train_path.shape)
X_test_path=X_test
X_test_path=X_test_path.reshape(-1,)
print(X_test_path.shape)
# Out:
# (74715,)
# (16984,)

# %% [markdown]
# ### Sauvegarde des jeux de données traités

# %%
with open(ds.get_RACINE_SAUVEGARDE() + 'X_train_path.pkl', 'wb') as f:
    pickle.dump(X_train_path, f)
with open(ds.get_RACINE_SAUVEGARDE() + 'X_test_path.pkl', 'wb') as f:
    pickle.dump(X_test_path, f)

# %%
print(X_train_path[:2])
print(y_train[:2])
print(X_test_path[:2])
print(y_test[:2])
# Out:
# ['D:/Manuel/PROJET/Rakuten_Images_Classification_TensorFlow/data/images/image_train/image_1287522730_product_4071377790.jpg'
#  'D:/Manuel/PROJET/Rakuten_Images_Classification_TensorFlow/data/images/image_train/image_834905540_product_68300767.jpg']
# [1560 1300]
# ['D:/Manuel/PROJET/Rakuten_Images_Classification_TensorFlow/data/images/image_train/image_1261376573_product_3898716869.jpg'
#  'D:/Manuel/PROJET/Rakuten_Images_Classification_TensorFlow/data/images/image_train/image_857241566_product_90956368.jpg']
# [1301 1140]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y_classes_converted = label_encoder.fit_transform(y_train)
#y_classes_train = label_encoder.transform(y_train)
# Maintenant, utilisez to_categorical
y_train_Network = to_categorical(y_classes_converted)
y_classes_converted = label_encoder.transform(y_test)
#y_classes_test = label_encoder.transform(y_test)
# Maintenant, utilisez to_categorical
y_test_Network = to_categorical(y_classes_converted)
print(y_train_Network.shape)
print(y_test_Network.shape)
with open(ds.get_RACINE_SAUVEGARDE() + 'y_train.pkl', 'wb') as f:
    pickle.dump(y_train, f)
with open(ds.get_RACINE_SAUVEGARDE() + 'y_test.pkl', 'wb') as f:
    pickle.dump(y_test, f)
# Out:
# (74715, 27)
# (16984, 27)

# %%
### augmentation des données
random_flip_left_right -> Retournez aléatoirement une image horizontalement (de gauche à droite)
random_flip_up_down -> Retournez aléatoirement une image verticalement (du haut vers  le bas)
random_brightness -> Ajuster la luminosité par un facteur aléatoire
random_contrast -> Ajuster le contraste par un facteur aléatoire
image.rot90 -> Rotation de 90 degrés

# %%
@tf.function
def augment_image(image):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.3)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    #image = tf.image.rot90(image, k=1) 
    image = tf.image.random_crop(image,[400, 400, 3])
    return image



@tf.function
def load_and_augment_image(filepath, resize=(IMGSIZE,IMGSIZE)):
    image = tf.io.read_file(filepath)
    image = tf.image.decode_jpeg(image, channels=3)
    image = augment_image(image)
    return tf.image.resize(image, resize)

@tf.function
def load_image(filepath, resize=(IMGSIZE,IMGSIZE)):
    im = tf.io.read_file(filepath)
    im = tf.image.decode_jpeg(im, channels=3)
    return tf.image.resize(im, resize)

dataset_train = tf.data.Dataset.from_tensor_slices((X_train_path, y_train_Network ))

dataset_train = dataset_train.map(lambda x, y : [load_and_augment_image(x),y], num_parallel_calls=-1).batch(BATCH_SIZE)
#dataset_train = dataset_train.map(lambda x, y : [load_image(x),y], num_parallel_calls=-1).batch(BATCH_SIZE)

dataset_test = tf.data.Dataset.from_tensor_slices((X_test_path, y_test_Network))

dataset_test = dataset_test.map(lambda x, y : [load_image(x),y], num_parallel_calls=-1).batch(BATCH_SIZE)

#dataset_train_aug = tf.data.Dataset.from_tensor_slices((X_train_path_aug, y_train_Network_aug))
#dataset_train_aug = dataset_train_aug.map(lambda x, y: [load_and_augment_image2(x), y], num_parallel_calls=-1).batch(32)

# %%
random_samples = X_train_path[:5]

# Créer une figure pour afficher les images
fig, axs = plt.subplots(5, 2, figsize=(10, 20))

for i, nom in enumerate(random_samples):
    print(i, nom)
    # Charger l'image originale
    original_image = load_image(nom)/255.0

    # Redimensionner l'image pour l'affichage
    #resized_image = tf.image.resize(original_image, (IMGSIZE, IMGSIZE))

    # Charger l'image à l'aide de la fonction load_image
    augmented_image = load_and_augment_image(nom)/255.0

    # Afficher l'image originale et l'image augmentée
    axs[i, 0].imshow(original_image)
    axs[i, 0].axis('off')
    axs[i, 0].set_title('Original Image')

    axs[i, 1].imshow(augmented_image)
    axs[i, 1].axis('off')
    axs[i, 1].set_title('Augmented Image')

plt.show()
# Out:
# 0 D:/Manuel/PROJET/Rakuten_Images_Classification_TensorFlow/data/images/image_train/image_1287522730_product_4071377790.jpg
# 1 D:/Manuel/PROJET/Rakuten_Images_Classification_TensorFlow/data/images/image_train/image_834905540_product_68300767.jpg
# 2 D:/Manuel/PROJET/Rakuten_Images_Classification_TensorFlow/data/images/image_train/image_1297966418_product_4137777134.jpg
# 3 D:/Manuel/PROJET/Rakuten_Images_Classification_TensorFlow/data/images/image_train/image_1249534556_product_3819979312.jpg
# 4 D:/Manuel/PROJET/Rakuten_Images_Classification_TensorFlow/data/images/image_train/image_1316245447_product_4200880271.jpg
# WARNING:tensorflow:5 out of the last 5 calls to <function load_image at 0x00000217D3938DC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function load_and_augment_image at 0x00000217D30D4DC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# @tf.function
# def load_image(filepath, resize=(500,500)):
#     im = tf.io.read_file(filepath)
#     im = tf.image.decode_png(im, channels=3)
#     return tf.image.resize(im, resize)
#
# dataset_train = tf.data.Dataset.from_tensor_slices((X_train_path, y_train_Network))
#
# dataset_train = dataset_train.map(lambda x, y : [load_image(x),y], num_parallel_calls=-1).batch(32)
#
# dataset_test = tf.data.Dataset.from_tensor_slices((X_test_path, y_test_Network))
#
# dataset_test = dataset_test.map(lambda x, y : [load_image(x),y], num_parallel_calls=-1).batch(32)

# %%
from tensorflow.keras.applications import VGG19
#  help(tf.keras.applications)
# Chargement du modèle VGG19
base_model =  VGG19(weights='imagenet', include_top=False,input_shape=(IMGSIZE,IMGSIZE,3))

niv1,niv2 = 0,0
for layer in base_model.layers[:FREEZE_LAYERS]:
    niv1  +=1
    layer.trainable = False
  
# Entrainement des derniers layers de classification
for layer in base_model.layers[FREEZE_LAYERS:]:
    niv2 += 1
    layer.trainable = True
base_model.summary()
print("Nb layers gelées : ",niv1)
print("nb layers dégelées : ", niv2)
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 400, 400, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 400, 400, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 200, 200, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 200, 200, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 200, 200, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 100, 100, 128)     0
#
#  block3_conv1 (Conv2D)       (None, 100, 100, 256)     295168
#
#  block3_conv2 (Conv2D)       (None, 100, 100, 256)     590080
#
#  block3_conv3 (Conv2D)       (None, 100, 100, 256)     590080
#
#  block3_conv4 (Conv2D)       (None, 100, 100, 256)     590080
#
#  block3_pool (MaxPooling2D)  (None, 50, 50, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 50, 50, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 50, 50, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 50, 50, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 50, 50, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 25, 25, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 25, 25, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 25, 25, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 25, 25, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 25, 25, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 12, 12, 512)       0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 9,439,232
# Non-trainable params: 10,585,152
# _________________________________________________________________
# Nb layers gelées :  17
# nb layers dégelées :  5

# %% [markdown]
# # II) Activation du meilleur modèle

# %%
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Conv2D, MaxPooling2D, BatchNormalization, LeakyReLU, Flatten
model = Sequential()
model.add(base_model) # Ajout du modèle EfficientB1
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu'))
#model.add(BatchNormalization())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(27, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 12, 12, 512)       20024384
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dropout (Dropout)           (None, 73728)             0
#
#  dense (Dense)               (None, 1024)              75498496
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 27)                27675
#
# =================================================================
# Total params: 96,600,155
# Trainable params: 86,015,003
# Non-trainable params: 10,585,152
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
savemodel = ds.get_RACINE_SAUVEGARDE() + SUFFIXE_FICHIER + '_model.keras'
trainacc  = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_train_acc.pkl'
valacc = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_val_acc.pkl'
loss = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_loss.pkl'
valloss = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_valloss.pkl'
dfpredict = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+ '_df_predict.csv'
testoriginal = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_y_test_original2.pkl'
predoriginal = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_test_pred_original2.pkl'

# %% [markdown]
# ### a) lancement de l'entrainement

# %%
from tensorflow.keras import callbacks
NBETAPE=6
checkpoint = callbacks.ModelCheckpoint(filepath=ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_checkpoint.keras',
                                       monitor='val_loss',
                                       save_best_only=True,
                                       save_weights_only=False,
                                       mode='min',
                                       save_freq='epoch')

# Réduction automatique du taux d'apprentissage

lr_plateau = callbacks.ReduceLROnPlateau(monitor = 'val_loss',
                            patience=4,
                            factor=0.5,
                            verbose=1,
                            mode='min')



training_history = model.fit(dataset_train, epochs=40, validation_data = dataset_test, callbacks=[lr_plateau])
# Out:
# Epoch 1/40
# 4670/4670 [==============================] - 1590s 340ms/step - loss: 2.9482 - accuracy: 0.1514 - val_loss: 2.5085 - val_accuracy: 0.2694 - lr: 1.0000e-04
# Epoch 2/40
# 4670/4670 [==============================] - 1607s 344ms/step - loss: 2.4177 - accuracy: 0.2851 - val_loss: 2.0498 - val_accuracy: 0.3898 - lr: 1.0000e-04
# Epoch 3/40
# 4670/4670 [==============================] - 1609s 344ms/step - loss: 2.0990 - accuracy: 0.3841 - val_loss: 1.9346 - val_accuracy: 0.4340 - lr: 1.0000e-04
# Epoch 4/40
# 4670/4670 [==============================] - 1612s 345ms/step - loss: 1.9376 - accuracy: 0.4310 - val_loss: 1.7786 - val_accuracy: 0.4821 - lr: 1.0000e-04
# Epoch 5/40
# 4670/4670 [==============================] - 1612s 345ms/step - loss: 1.8360 - accuracy: 0.4586 - val_loss: 1.7263 - val_accuracy: 0.4911 - lr: 1.0000e-04
# Epoch 6/40
# 4670/4670 [==============================] - 1601s 343ms/step - loss: 1.7721 - accuracy: 0.4775 - val_loss: 1.6985 - val_accuracy: 0.4951 - lr: 1.0000e-04
# Epoch 7/40
# 4670/4670 [==============================] - 1591s 341ms/step - loss: 1.7181 - accuracy: 0.4912 - val_loss: 1.6590 - val_accuracy: 0.5048 - lr: 1.0000e-04
# Epoch 8/40
# 4670/4670 [==============================] - 1590s 340ms/step - loss: 1.6780 - accuracy: 0.5017 - val_loss: 1.6822 - val_accuracy: 0.5088 - lr: 1.0000e-04
# Epoch 9/40
# 4670/4670 [==============================] - 1590s 340ms/step - loss: 1.6450 - accuracy: 0.5122 - val_loss: 1.6482 - val_accuracy: 0.5197 - lr: 1.0000e-04
# Epoch 10/40
# 4670/4670 [==============================] - 1589s 340ms/step - loss: 1.6221 - accuracy: 0.5186 - val_loss: 1.6045 - val_accuracy: 0.5253 - lr: 1.0000e-04
# Epoch 11/40
# 4670/4670 [==============================] - 1587s 340ms/step - loss: 1.5971 - accuracy: 0.5254 - val_loss: 1.6562 - val_accuracy: 0.5134 - lr: 1.0000e-04
# Epoch 12/40
# 4670/4670 [==============================] - 1586s 340ms/step - loss: 1.5722 - accuracy: 0.5284 - val_loss: 1.6268 - val_accuracy: 0.5216 - lr: 1.0000e-04
# Epoch 13/40
# 4670/4670 [==============================] - 1585s 339ms/step - loss: 1.5572 - accuracy: 0.5344 - val_loss: 1.6518 - val_accuracy: 0.5176 - lr: 1.0000e-04
# Epoch 14/40
# 4670/4670 [==============================] - ETA: 0s - loss: 1.5435 - accuracy: 0.5375
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 4670/4670 [==============================] - 1589s 340ms/step - loss: 1.1709 - accuracy: 0.6360 - val_loss: 1.6476 - val_accuracy: 0.5565 - lr: 2.5000e-05
# Epoch 30/40
# 4670/4670 [==============================] - 1593s 341ms/step - loss: 1.1328 - accuracy: 0.6451 - val_loss: 1.6183 - val_accuracy: 0.5647 - lr: 1.2500e-05
# Epoch 31/40
# 4670/4670 [==============================] - 1591s 341ms/step - loss: 1.1182 - accuracy: 0.6490 - val_loss: 1.6215 - val_accuracy: 0.5675 - lr: 1.2500e-05
# Epoch 32/40
# 4670/4670 [==============================] - 1583s 339ms/step - loss: 1.1088 - accuracy: 0.6503 - val_loss: 1.6239 - val_accuracy: 0.5671 - lr: 1.2500e-05
# Epoch 33/40
# 4670/4670 [==============================] - ETA: 0s - loss: 1.1050 - accuracy: 0.6508
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 4670/4670 [==============================] - 1581s 338ms/step - loss: 1.1050 - accuracy: 0.6508 - val_loss: 1.6829 - val_accuracy: 0.5648 - lr: 1.2500e-05
# Epoch 34/40
# 4670/4670 [==============================] - 1580s 338ms/step - loss: 1.0870 - accuracy: 0.6560 - val_loss: 1.6450 - val_accuracy: 0.5700 - lr: 6.2500e-06
# Epoch 35/40
# 4670/4670 [==============================] - 1580s 338ms/step - loss: 1.0809 - accuracy: 0.6569 - val_loss: 1.6462 - val_accuracy: 0.5721 - lr: 6.2500e-06
# Epoch 36/40
# 4670/4670 [==============================] - 1580s 338ms/step - loss: 1.0770 - accuracy: 0.6573 - val_loss: 1.6684 - val_accuracy: 0.5682 - lr: 6.2500e-06
# Epoch 37/40
# 4670/4670 [==============================] - ETA: 0s - loss: 1.0695 - accuracy: 0.6574
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 4670/4670 [==============================] - 1579s 338ms/step - loss: 1.0695 - accuracy: 0.6574 - val_loss: 1.7045 - val_accuracy: 0.5689 - lr: 6.2500e-06
# Epoch 38/40
# 4670/4670 [==============================] - 1579s 338ms/step - loss: 1.0640 - accuracy: 0.6620 - val_loss: 1.6727 - val_accuracy: 0.5712 - lr: 3.1250e-06
# Epoch 39/40
# 4670/4670 [==============================] - 1578s 338ms/step - loss: 1.0615 - accuracy: 0.6616 - val_loss: 1.6797 - val_accuracy: 0.5694 - lr: 3.1250e-06
# Epoch 40/40
# 4670/4670 [==============================] - 1578s 338ms/step - loss: 1.0548 - accuracy: 0.6622 - val_loss: 1.6869 - val_accuracy: 0.5716 - lr: 3.1250e-06

# %%
print("Sauvegarde des poids du modèle ... ")
#model.save_weights(saveweights)
model.save(savemodel)
print(savemodel)
print("-"*20)

train_acc = training_history.history['accuracy']
val_acc = training_history.history['val_accuracy']
tloss = training_history.history['loss']
tvalloss=training_history.history['val_loss']

print("Sauvegardes des precisions et les des pertes ... ")
with open(trainacc, 'wb') as f:
    pickle.dump(train_acc, f)
with open(valacc, 'wb') as f:
    pickle.dump(val_acc, f)
with open(loss, 'wb') as f:
    pickle.dump(tloss, f)
with open(valloss, 'wb') as f:
    pickle.dump(tvalloss, f)
#print(trainacc)
#print(valacc)
#print(loss)
#print(valloss)
print("-"*20)
    
y_test_original = np.argmax(y_test_Network, axis=1)
#print(y_test_Network[0])
y_test_original2=label_encoder.inverse_transform(y_test_original)

predictions = model.predict(dataset_test)
y_pred = np.argmax(predictions, axis=1)
test_pred_original2=label_encoder.inverse_transform(y_pred)

#print("-"*20)

top5_df = pd.DataFrame({'prdtypecode': y_test_original2,'predict': test_pred_original2})

df_cross=pd.crosstab(top5_df['prdtypecode'], top5_df['predict'],normalize='index')

df_pred = pd.DataFrame()
for c in Lcat:
    s = df_cross.loc[c].sort_values(ascending=False)[:5]
    df_temp = pd.DataFrame([{'Categorie':c,'predict':s.index[0],'pourc':s.values[0],'predict2':s.index[1],'pourc2':s.values[1],'predict3':s.index[2],'pourc3':s.values[2]}])
    df_pred = pd.concat([df_pred, df_temp], ignore_index=True)

print("Sauvegardes des rerultats ... ")
df_pred.to_csv(dfpredict)
with open(testoriginal, 'wb') as f:
    pickle.dump(y_test_original2, f)
with open(predoriginal, 'wb') as f:
    pickle.dump(test_pred_original2, f)
#print(testoriginal)
#print(predoriginal)
# Out:
# Sauvegarde des poids du modèle ...
# --------------------
# Sauvegardes des precisions et les des pertes ...
# --------------------
# 1062/1062 [==============================] - 239s 225ms/step
# Sauvegardes des rerultats ...

# %% [markdown]
# ### b) affichage des precisions et des pertes par époque

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(tloss)
plt.plot(tvalloss)
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right')

   

plt.subplot(122)
plt.plot(train_acc)
plt.plot(val_acc)
plt.title('Model acc by epoch')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right');

# %% [markdown]
# ### c) affichage des 3 meilleurs prédictions par catégorie
# classé par ordre d'échantillonage obtenu après over et under sampling

# %%
#=========================================================================
dfp=pd.read_csv(dfpredict)
dfs=pd.read_csv(ds.get_RACINE_SAUVEGARDE()+STRATEGIE) # effectifs par classe retenu après over et under sampling
dfs.rename({'Unnamed: 0':'Categorie'},axis=1,inplace=True)
df_resume=dfs.merge(dfp,on='Categorie',how='inner')
df_resume.drop('Unnamed: 0',axis=1,inplace=True)
df_resume.head(27)
# Out:
#     Categorie  Qunatity  predict     pourc  predict2    pourc2  predict3  \
# 0        2583      5000     2583  0.818805      2585  0.025955      2522
# 1        1560      4058     1560  0.513300      2060  0.119212      1320
# 2        1300      4036     1300  0.791873        50  0.041625      2585
# 3        2060      3994     2060  0.445445      1920  0.068068      1280
# 4        2522      3991     2522  0.633267      2583  0.057114      2403
# 5        1280      3896     1280  0.344969      1300  0.208419      1140
# 6        2403      3819     2403  0.630366      2280  0.108901        10
# 7        2280      3808     2280  0.746849      2403  0.084034        10
# 8        1920      3442     1920  0.756098      1560  0.058072      2060
# 9        1160      3162     1160  0.915297      2462  0.017699      1281
# 10       1320      2593     1320  0.341049      1280  0.098765      2583
# 11         10      2493       10  0.418941      2705  0.202247      2280
# 12       2705      2209     2705  0.483696        10  0.313406      2403
# 13       1140      2137     1140  0.608614      1280  0.071161      1180
# 14       2582      2071     2582  0.306950      1560  0.156371      2060
# 15         40      2006       40  0.478088      2905  0.077689      2462
# 16       2585      2000     2585  0.258517      2583  0.174349      1300
# 17       1302      2000     1302  0.224900      1280  0.172691      1300
# 18       1281      2000     1281  0.265700      1280  0.152174      2403
# 19         50      2000       50  0.377976      1300  0.145833        60
# 20       2462      2000     2462  0.623239        40  0.095070      2403
# 21       2905      2000     2905  0.304598        40  0.298851      2705
# 22         60      2000       60  0.728916        50  0.108434      1300
# 23       2220      2000     2220  0.339394      1302  0.096970      1320
# 24       1301      2000     1301  0.534161      1320  0.086957      2522
# 25       1940      2000     1940  0.664596      2583  0.055901      1280
# 26       1180      2000     1180  0.418301      1140  0.137255      1281
#
#       pourc3
# 0   0.023017
# 1   0.054187
# 2   0.031715
# 3   0.058058
# 4   0.037074
# 5   0.106776
# 6   0.075393
# 7   0.065126
# 8   0.047619
# 9   0.015171
# 10  0.078704
# 11  0.121990
# 12  0.047101
# 13  0.041199
# 14  0.121622
# 15  0.073705
# 16  0.148297
# 17  0.104418
# 18  0.065217
# 19  0.065476
# 20  0.070423
# 21  0.212644
# 22  0.036145
# 23  0.084848
# 24  0.068323
# 25  0.037267
# 26  0.091503

# %% [markdown]
# ### d) matrice de confusion

# %%
import itertools # Pour créer des itérateurs
#cnf_matrix = confusion_matrix(y_test, test_pred_orinal,labels=[10,2280,2403,2705,40,50,2462,1280,1281])
cnf_matrix = confusion_matrix(y_test, test_pred_original2,labels=sorted(list(set(y_test_original2))))
#print(cnf_matrix)


classes=sorted(list(set(y_test_original2)))
b=list(set(y_test_original2))

plt.figure(figsize=(15,15))

plt.imshow(cnf_matrix, interpolation='nearest',cmap='Blues')
plt.title("Matrice de confusion")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes,rotation=90)
plt.yticks(tick_marks, classes)

for i, j in itertools.product(range(cnf_matrix.shape[0]), range(cnf_matrix.shape[1])):
    plt.text(j, i, cnf_matrix[i, j],
             horizontalalignment = "center",
             color = "white" if cnf_matrix[i, j] > ( cnf_matrix.max() / 2) else "black")

plt.ylabel('Vrais labels')
plt.xlabel('Labels prédits')
plt.show()

# %%
top5_df = pd.DataFrame({'prdtypecode': y_test_original2,'predict': test_pred_original2})
df_cross=pd.crosstab(top5_df['prdtypecode'], top5_df['predict'],normalize='index')
df_cross
# Out:
# predict          10        40        50        60        1140      1160  \
# prdtypecode
# 10           0.418941  0.028892  0.000000  0.001605  0.003210  0.006421
# 40           0.011952  0.478088  0.045817  0.027888  0.023904  0.033865
# 50           0.002976  0.002976  0.377976  0.065476  0.038690  0.014881
# 60           0.000000  0.006024  0.108434  0.728916  0.000000  0.000000
# 1140         0.005618  0.005618  0.031835  0.000000  0.608614  0.018727
# 1160         0.001264  0.006321  0.001264  0.000000  0.008850  0.915297
# 1180         0.019608  0.013072  0.006536  0.000000  0.137255  0.013072
# 1280         0.001027  0.002053  0.017454  0.001027  0.106776  0.008214
# 1281         0.026570  0.019324  0.028986  0.004831  0.024155  0.043478
# 1300         0.000000  0.001982  0.041625  0.003964  0.007929  0.000000
# 1301         0.000000  0.000000  0.024845  0.000000  0.012422  0.006211
# 1302         0.000000  0.000000  0.026104  0.000000  0.028112  0.000000
print("Evaluation détaillée de la Classification par RDF :\n \n" ,
      (classification_report(y_test_original2, test_pred_original2)))
# Out:
# Précision de la prédiction: 57.1596796985398 %
# Evaluation détaillée de la Classification par RDF :
#
#                precision    recall  f1-score   support
#
#           10       0.42      0.42      0.42       623
#           40       0.63      0.48      0.54       502
#           50       0.30      0.38      0.34       336
#           60       0.68      0.73      0.70       166
#         1140       0.50      0.61      0.55       534
#         1160       0.89      0.92      0.90       791
#         1180       0.37      0.42      0.39       153
#         1280       0.42      0.34      0.38       974
#         1281       0.33      0.27      0.30       414
#         1300       0.56      0.79      0.66      1009
#         1301       0.48      0.53      0.51       161
#         1302       0.28      0.22      0.25       498
#         1320       0.34      0.34      0.34       648
#         1560       0.60      0.51      0.55      1015
#         1920       0.78      0.76      0.77       861
#         1940       0.53      0.66      0.59       161
#         2060       0.47      0.45      0.46       999
#         2220       0.25      0.34      0.29       165
#         2280       0.75      0.75      0.75       952
#         2403       0.67      0.63      0.65       955
#         2462       0.47      0.62      0.53       284
#         2522       0.58      0.63      0.61       998
#         2582       0.58      0.31      0.40       518
#         2583       0.77      0.82      0.80      2042
#         2585       0.26      0.26      0.26       499
#         2705       0.51      0.48      0.50       552
#         2905       0.40      0.30      0.34       174
#
#     accuracy                           0.57     16984
#    macro avg       0.51      0.52      0.51     16984
# weighted avg       0.57      0.57      0.57     16984

# %% [markdown]
# ### f) Résumé de la classification obtenue

# %%
df_pred = pd.DataFrame()
for c in Lcat:
    print(c, '   ------   ', catdict[c])
    s = df_cross.loc[c].sort_values(ascending=False)[:5]
    df_temp = pd.DataFrame([{'Categorie':c,'predict':s.index[0],'pourc':s.values[0],'predict2':s.index[1],'pourc2':s.values[1],'predict3':s.index[2],'pourc3':s.values[2]}])
    df_pred = pd.concat([df_pred, df_temp], ignore_index=True)
    for index, value in s.items():  # Change ici
        print(f"  : {index},  : {np.round(value*100,2)} % , {catdict[index]}")
df_pred.to_csv('dfpredict')
# Out:
# 10    ------    livres
#   : 10,  : 41.89 % , livres
#   : 2705,  : 20.22 % , bds et livres
#   : 2280,  : 12.2 % , magazines
#   : 2403,  : 10.75 % , livres et bds
#   : 2522,  : 4.33 % , produits de papeterie et rangement bureau
# 40    ------    jeux video pour pc et consoles
#   : 40,  : 47.81 % , jeux video pour pc et consoles
#   : 2905,  : 7.77 % , Jeu En téléchargement
#   : 2462,  : 7.37 % , consoles de jeux video et jeux videos
#   : 1300,  : 5.18 % , Petites voitures (jouets) et maquettes
#   : 50,  : 4.58 % ,  accesoires jeux video
# 50    ------     accesoires jeux video
#   : 50,  : 37.8 % ,  accesoires jeux video
#   : 1300,  : 14.58 % , Petites voitures (jouets) et maquettes
#   : 60,  : 6.55 % , consoles de jeux video
#   : 2462,  : 6.25 % , consoles de jeux video et jeux videos
#   : 2583,  : 5.65 % , accesoires de piscine
# 60    ------    consoles de jeux video
#   : 60,  : 72.89 % , consoles de jeux video
#   : 50,  : 10.84 % ,  accesoires jeux video
#   : 1300,  : 3.61 % , Petites voitures (jouets) et maquettes
obilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 2582,  : 30.69 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 1560,  : 15.64 % , Mobilier et produits decoration/rangement pour la maison
#   : 2060,  : 12.16 % , lampes et accesoires decoration pour maison
#   : 2583,  : 9.07 % , accesoires de piscine
#   : 2585,  : 5.98 % , outillage et accesoires pour jardinage
# 2583    ------    accesoires de piscine
#   : 2583,  : 81.88 % , accesoires de piscine
#   : 2585,  : 2.6 % , outillage et accesoires pour jardinage
#   : 2522,  : 2.3 % , produits de papeterie et rangement bureau
#   : 1320,  : 2.11 % , sacs pour femmes et accesore petite enfance
#   : 1300,  : 1.71 % , Petites voitures (jouets) et maquettes
# 2585    ------    outillage et accesoires pour jardinage
#   : 2585,  : 25.85 % , outillage et accesoires pour jardinage
#   : 2583,  : 17.43 % , accesoires de piscine
#   : 1300,  : 14.83 % , Petites voitures (jouets) et maquettes
#   : 2060,  : 7.21 % , lampes et accesoires decoration pour maison
#   : 2522,  : 7.01 % , produits de papeterie et rangement bureau
# 2705    ------    bds et livres
#   : 2705,  : 48.37 % , bds et livres
#   : 10,  : 31.34 % , livres
#   : 2403,  : 4.71 % , livres et bds
#   : 2280,  : 4.17 % , magazines
#   : 2905,  : 3.26 % , Jeu En téléchargement
# 2905    ------    Jeu En téléchargement
#   : 2905,  : 30.46 % , Jeu En téléchargement
#   : 40,  : 29.89 % , jeux video pour pc et consoles
#   : 2705,  : 21.26 % , bds et livres
#   : 1140,  : 6.32 % , produits derives “geeks” et figurines
#   : 1280,  : 2.3 % , jouets, peluches, poupees

# %% [markdown]
# # III) Tracé sur 40 epoques
# ### a) Ajout au tableau général

# %%
CNN="CNN15"
PGM="Model_Img_Reseau_RGB_VGG19_V01"
LIBBELLE="VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR50-CC1024-CC1024-DR50"

# %%
df_val_accuracy= pd.read_csv(ds.get_RACINE_SAUVEGARDE()+'df_val_accuracy.csv')
print(df_val_accuracy['id'].value_counts())
print(df_val_accuracy['libelle'].value_counts())
df_val_accuracy.head()
# Out:
# id
# UNDER01    40
# UNDER03    40
# CNN15      40
# CNN13      40
# CNN12      40
# CNN11      40
# CNN32      40
# CNN31      40
# CNN30      40
# CNN21      40
# CNN20      40
# CNN24      40
# CNN23      40
# CNN22      40
# CNN02      40
# CNN01      40
# CNN10      40
# CNN08      40
# CNN07      40
# CNN06      40
# CNN04      40
# CNN05      40
# CNN03      40
# UNDER05    40
# UNDER06    40
# UNDER04    40
# UNDER02    40
# CNN16      40
# Name: count, dtype: int64
# libelle
# undersampling max 2400                                                                        40
# undersampling max 764                                                                         40
# VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR40-CC1024-NORM-CC1024-DR40                         40
# VGG16 Adam 5000-2000 SIZE400 DeFreeze 4  - BATCH32                                            40
# VGG16 Adam 5000-2000 SIZE400 DeFreeze 4 -  DR40-CC1024-NORM-CC512-DR40 - BATCH32              40
# VGG16 Adam 5000-2000 SIZE400 DeFreeze 4 -  DR40-CC1024-DR40-CC1024 - BATCH32                  40
# RESNET50 Adam 4000-2000 SIZE400 DeFreeze 50 DR40-CC1024-NORM-CC512-DR30 BATCH 32              40
# RESNET50 Adam 4000-2000 SIZE400 DeFreeze 30 DR40-CC1024-NORM-CC512-DR40 BATCH 32              40
# RESNET50 Adam 4000-2000 SIZE400 DeFreeze 30 DR30-CC1024-NORM-CC512-DR30 BATCH 32              40
# InceptionV3 Adam 4000-2000 SIZE400  DeFreeze 43 DR30-CC1024-CC512-DR30 - BATCH16              40
# InceptionV3 Adam 4000-2000 SIZE400 DeFreeze 43  DR40-CC1024-NORM-CC512-DR40- BATCH32          40
# InceptionV3 Adam 4000-2000 SIZE400 DeFreeze 43  DR30-CC1024-NORM-512-256-DR30 - BATCH16       40
# InceptionV3 Adam 4000-2000 SIZE400 DeFreeze 43  DR40-CC1024-NORM-CC512-DR30 - BATCH16         40
# InceptionV3 Adam 4000-2000 SIZE400 DeFreeze 43 DR40-CC1024-NORM-1024-DR40 - BATCH16           40
# EfficientNetB1 Adam 4000-2000 SIZE400 DeFreeze  POOL-DR40-CC1024-NORM-CC1024-DR40- BATCH16    40
# EfficientNetB1 Adam 4000-2000 SIZE400 DeFreeze DR50-CC1024-NORM-CC1024-DR40-BATCH16           40
# VGG16 Adam 4000-2000 SIZE400 DeFreeze  DR50-CC1024-NORM-CC1024-40                             40
# modele perso RGB max 5000 Generation l1=0.01 DR10                                             40
# modele perso RGB max 4000 Generation l1=0.001 DR10                                            40
# modele perso RGB max 2500 lr=0.0001 DR20                                                      40
# modele perso RGB max 2500 lr=0.0001 DR10                                                      40
# efficientNet RGB max 4000 lr=0.01->0.0042 DR20-20                                             40
# efficientNet RGB max 2500 lr=0.01->0.0042 DR20-20                                             40
# undersampling max 2400 L1=0.0001                                                              40
# undersampling max 2400 L2=0.0001                                                              40
# undersampling max 2400 avec BatchNormalization                                                40
# undersampling max 2400 class_weight                                                           40
# VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR40-CC1024-CC1024-DR40                              40
# Name: count, dtype: int64
#    Unnamed: 0  Unnamed: 0.1  Epoch  val_accuracy  \
# 0           0           0.0      1      0.181025
# 1           1           1.0      2      0.214916
# 2           2           2.0      3      0.211974
# 3           3           3.0      4      0.223237
# 4           4           4.0      5      0.230238
#
#                                 programme                 libelle       id
# 0  Modele_IMG_Reseau_images_undersampling  undersampling max 2400  UNDER01
# 1  Modele_IMG_Reseau_images_undersampling  undersampling max 2400  UNDER01
# 2  Modele_IMG_Reseau_images_undersampling  undersampling max 2400  UNDER01
# 3  Modele_IMG_Reseau_images_undersampling  undersampling max 2400  UNDER01
# 4  Modele_IMG_Reseau_images_undersampling  undersampling max 2400  UNDER01

# %%
if len(val_acc) <40:
    raise SystemExit("Arrêt de l'exécution de la cellule car la longueur de val_acc est imcompatible avec la suite du traitement !")
df_val_accuracy= pd.read_csv(ds.get_RACINE_SAUVEGARDE() +'df_val_accuracy.csv')
df_val_accuracy.drop('Unnamed: 0',axis=1,inplace=True)
print(df_val_accuracy.head())
print('*******************')
print(df_val_accuracy.tail())
print('*******************')
df_val_accuracy2 = pd.DataFrame(list(val_acc)[:40],index=np.arange(1 , 41, 1),columns =['val_accuracy'])
print(df_val_accuracy2.head())
print('*******************')
df_val_accuracy2['programme']=PGM
df_val_accuracy2['libelle']=LIBBELLE
df_val_accuracy2['id']=CNN
df_val_accuracy2.reset_index(inplace=True)
df_val_accuracy2 = df_val_accuracy2.rename(columns={"index": "Epoch"})
df_val_accuracy=df_val_accuracy[df_val_accuracy['id'] != CNN]
df_val_accuracy = pd.concat([df_val_accuracy,df_val_accuracy2])
df_val_accuracy.to_csv(ds.get_RACINE_SAUVEGARDE() +'df_val_accuracy.csv')
print(df_val_accuracy.head())
print('*******************')
print(df_val_accuracy.tail())
# Out:
#    Unnamed: 0.1  Epoch  val_accuracy                               programme  \
# 0           0.0      1      0.181025  Modele_IMG_Reseau_images_undersampling
# 1           1.0      2      0.214916  Modele_IMG_Reseau_images_undersampling
# 2           2.0      3      0.211974  Modele_IMG_Reseau_images_undersampling
# 3           3.0      4      0.223237  Modele_IMG_Reseau_images_undersampling
# 4           4.0      5      0.230238  Modele_IMG_Reseau_images_undersampling
#
#                   libelle       id
# 0  undersampling max 2400  UNDER01
# 1  undersampling max 2400  UNDER01
# 2  undersampling max 2400  UNDER01
# 3  undersampling max 2400  UNDER01
# 4  undersampling max 2400  UNDER01
# *******************
#       Unnamed: 0.1  Epoch  val_accuracy                       programme  \
# 1115           NaN     36      0.574894  Model_Img_Reseau_RGB_VGG19_V01
# 1116           NaN     37      0.576778  Model_Img_Reseau_RGB_VGG19_V01
# 1117           NaN     38      0.575188  Model_Img_Reseau_RGB_VGG19_V01
# 1118           NaN     39      0.575247  Model_Img_Reseau_RGB_VGG19_V01
# 1119           NaN     40      0.576366  Model_Img_Reseau_RGB_VGG19_V01
#
#                                                 libelle     id
# 1115  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR40-...  CNN16
# 1116  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR40-...  CNN16
# 1117  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR40-...  CNN16
# 1118  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR40-...  CNN16
# 1119  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR40-...  CNN16
# *******************
#    val_accuracy
# 1      0.269371
# 2      0.389779
# 3      0.433997
# 4      0.482101
# 5      0.491109
# *******************
#    Unnamed: 0.1  Epoch  val_accuracy                               programme  \
# 0           0.0      1      0.181025  Modele_IMG_Reseau_images_undersampling
# 1           1.0      2      0.214916  Modele_IMG_Reseau_images_undersampling
# 2           2.0      3      0.211974  Modele_IMG_Reseau_images_undersampling
# 3           3.0      4      0.223237  Modele_IMG_Reseau_images_undersampling
# 4           4.0      5      0.230238  Modele_IMG_Reseau_images_undersampling
#
#                   libelle       id
# 0  undersampling max 2400  UNDER01
# 1  undersampling max 2400  UNDER01
# 2  undersampling max 2400  UNDER01
# 3  undersampling max 2400  UNDER01
# 4  undersampling max 2400  UNDER01
# *******************
#     Unnamed: 0.1  Epoch  val_accuracy                       programme  \
# 35           NaN     36      0.568241  Model_Img_Reseau_RGB_VGG19_V01
# 36           NaN     37      0.568947  Model_Img_Reseau_RGB_VGG19_V01
# 37           NaN     38      0.571244  Model_Img_Reseau_RGB_VGG19_V01
# 38           NaN     39      0.569418  Model_Img_Reseau_RGB_VGG19_V01
# 39           NaN     40      0.571597  Model_Img_Reseau_RGB_VGG19_V01
#
#                                               libelle     id
# 35  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR50-...  CNN15
# 36  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR50-...  CNN15
# 37  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR50-...  CNN15
# 38  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR50-...  CNN15
# 39  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR50-...  CNN15

# %%
df_accuracy= pd.read_csv(ds.get_RACINE_SAUVEGARDE()+'df_accuracy.csv')
df_accuracy.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Epoch  accuracy  \
# 0           0           0.0      1  0.139686
# 1           1           1.0      2  0.186874
# 2           2           2.0      3  0.205952
# 3           3           3.0      4  0.220996
# 4           4           4.0      5  0.234594
#
#                                 programme                 libelle       id
# 0  Modele_IMG_Reseau_images_undersampling  undersampling max 2400  UNDER01
# 1  Modele_IMG_Reseau_images_undersampling  undersampling max 2400  UNDER01
# 2  Modele_IMG_Reseau_images_undersampling  undersampling max 2400  UNDER01
# 3  Modele_IMG_Reseau_images_undersampling  undersampling max 2400  UNDER01
# 4  Modele_IMG_Reseau_images_undersampling  undersampling max 2400  UNDER01

# %%
if len(train_acc) < 40:
    raise SystemExit("Arrêt de l'exécution de la cellule car la longueur de train_acc est imcompatible avec la suite du traitement !")
df_val_accuracy= pd.read_csv(ds.get_RACINE_SAUVEGARDE() +'df_accuracy.csv')
df_val_accuracy.drop('Unnamed: 0',axis=1,inplace=True)
print(df_val_accuracy.head())
print('*******************')
df_val_accuracy2 = pd.DataFrame(list(train_acc)[:40],index=np.arange(1 , 41, 1),columns =['accuracy'])
print(df_val_accuracy2.head())
print('*******************')
df_val_accuracy2['programme']=PGM
df_val_accuracy2['libelle']=LIBBELLE
df_val_accuracy2['id']=CNN
df_val_accuracy2.reset_index(inplace=True)
df_val_accuracy2 = df_val_accuracy2.rename(columns={"index": "Epoch"})
df_val_accuracy=df_val_accuracy[df_val_accuracy['id'] != CNN]
df_val_accuracy = pd.concat([df_val_accuracy,df_val_accuracy2])
df_val_accuracy.to_csv(ds.get_RACINE_SAUVEGARDE() +'df_accuracy.csv')
print(df_val_accuracy.head())
print('*******************')
print(df_val_accuracy.tail())
# Out:
#    Unnamed: 0.1  Epoch  accuracy                               programme  \
# 0           0.0      1  0.139686  Modele_IMG_Reseau_images_undersampling
# 1           1.0      2  0.186874  Modele_IMG_Reseau_images_undersampling
# 2           2.0      3  0.205952  Modele_IMG_Reseau_images_undersampling
# 3           3.0      4  0.220996  Modele_IMG_Reseau_images_undersampling
# 4           4.0      5  0.234594  Modele_IMG_Reseau_images_undersampling
#
#                   libelle       id
# 0  undersampling max 2400  UNDER01
# 1  undersampling max 2400  UNDER01
# 2  undersampling max 2400  UNDER01
# 3  undersampling max 2400  UNDER01
# 4  undersampling max 2400  UNDER01
# *******************
#    accuracy
# 1  0.151362
# 2  0.285137
# 3  0.384140
# 4  0.430998
# 5  0.458623
# *******************
#    Unnamed: 0.1  Epoch  accuracy                               programme  \
# 0           0.0      1  0.139686  Modele_IMG_Reseau_images_undersampling
# 1           1.0      2  0.186874  Modele_IMG_Reseau_images_undersampling
# 2           2.0      3  0.205952  Modele_IMG_Reseau_images_undersampling
# 3           3.0      4  0.220996  Modele_IMG_Reseau_images_undersampling
# 4           4.0      5  0.234594  Modele_IMG_Reseau_images_undersampling
#
#                   libelle       id
# 0  undersampling max 2400  UNDER01
# 1  undersampling max 2400  UNDER01
# 2  undersampling max 2400  UNDER01
# 3  undersampling max 2400  UNDER01
# 4  undersampling max 2400  UNDER01
# *******************
#     Unnamed: 0.1  Epoch  accuracy                       programme  \
# 35           NaN     36  0.657311  Model_Img_Reseau_RGB_VGG19_V01
# 36           NaN     37  0.657378  Model_Img_Reseau_RGB_VGG19_V01
# 37           NaN     38  0.662036  Model_Img_Reseau_RGB_VGG19_V01
# 38           NaN     39  0.661634  Model_Img_Reseau_RGB_VGG19_V01
# 39           NaN     40  0.662183  Model_Img_Reseau_RGB_VGG19_V01
#
#                                               libelle     id
# 35  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR50-...  CNN15
# 36  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR50-...  CNN15
# 37  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR50-...  CNN15
# 38  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR50-...  CNN15
# 39  VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR50-...  CNN15

# %%
# Labels des axes
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

# Courbe de la précision sur l'échantillon d'entrainement
plt.plot(np.arange(1 , 41, 1),
         training_history.history['accuracy'],
         label = 'Training Accuracy',
         color = 'blue')

# Courbe de la précision sur l'échantillon de test
plt.plot(np.arange(1 ,41, 1),
         training_history.history['val_accuracy'],
         label = 'Validation Accuracy',
         color = 'red')

# Affichage de la légende
plt.legend()

# Affichage de la figure
plt.show()

# %%
df_report= pd.read_csv(ds.get_RACINE_SAUVEGARDE() +'df_report.csv')
df_report.head()
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Categorie  precision  \
# 0             0           0.0           0.0         0.0        10   0.573668
# 1             1           1.0           1.0         1.0        40   0.555094
# 2             2           2.0           2.0         2.0        50   0.555556
# 3             3           3.0           3.0         3.0        60   0.736842
# 4             4           4.0           4.0         4.0      1140   0.636197
#
#      recall  f1-score  support              programme  \
# 0  0.587480  0.580492    623.0  Modele_IMG_Reseau_RGB
# 1  0.531873  0.543235    502.0  Modele_IMG_Reseau_RGB
# 2  0.446429  0.495050    336.0  Modele_IMG_Reseau_RGB
# 3  0.754491  0.745562    167.0  Modele_IMG_Reseau_RGB
# 4  0.651685  0.643848    534.0  Modele_IMG_Reseau_RGB
#
#                                              libelle     id
# 0  efficientNet RGB max 4000 lr=0.01->0.0042 DR20-20  CNN05
# 1  efficientNet RGB max 4000 lr=0.01->0.0042 DR20-20  CNN05
# 2  efficientNet RGB max 4000 lr=0.01->0.0042 DR20-20  CNN05
# 3  efficientNet RGB max 4000 lr=0.01->0.0042 DR20-20  CNN05
# 4  efficientNet RGB max 4000 lr=0.01->0.0042 DR20-20  CNN05

# %%
report_dict = classification_report(y_test, test_pred_original2, output_dict=True)

# Conversion du rapport de classification en DataFrame
df_report2 = pd.DataFrame(report_dict).transpose()
df_report2['programme']=PGM
df_report2['libelle']=LIBBELLE
df_report2['id']=CNN
df_report2.reset_index(inplace=True)
df_report2 = df_report2.rename(columns={"index": "Categorie"})
df_report=df_report[df_report['id'] != CNN]
df_report = pd.concat([df_report,df_report2])
#df_report.drop('Unnamed: 0',axis=1,inplace=True)
df_report.to_csv(ds.get_RACINE_SAUVEGARDE() +'df_report.csv')
df_report.tail(50)
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 
GG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR50-...  CNN15
# 29   VGG19 Adam 5000-2000 SIZE400 DeFreeze 5  DR50-...  CNN15

# %% [markdown]
# ###  RECUPERER  LES DONNEES SAUVAGARDEES

# %%
saveweights = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_weights.keras'
trainacc  = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_train_acc.pkl'
valacc = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_val_acc.pkl'
loss = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_loss.pkl'
valloss = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_valloss.pkl'
dfpredict = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+ '_df_predict.csv'
testoriginal = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_y_test_original2.pkl'
predoriginal = ds.get_RACINE_SAUVEGARDE()+SUFFIXE_FICHIER+'_test_pred_original2.pkl'

# %%
import pickle
with open(trainacc, 'rb') as f:
    train_acc = pickle.load(f)
with open(valacc, 'rb') as f:
    val_acc = pickle.load(f)
with open(loss, 'rb') as f:
    tloss = pickle.load(f)
with open(valloss, 'rb') as f:
    tvalloss = pickle.load(f)

# %% [markdown]
# ### b) affichage des precisions et des pertes par époque

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(tloss)
plt.plot(tvalloss)
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right')

plt.subplot(122)
plt.plot(train_acc)
plt.plot(val_acc)
plt.title('Model acc by epoch')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right');

# %% [markdown]
# ### c) affichage des 3 meilleurs prédictions par catégorie
# classé par ordre d'échantillonage obtenu après over et under sampling

# %%
#=========================================================================
dfp=pd.read_csv(dfpredict)
dfs=pd.read_csv(ds.get_RACINE_SAUVEGARDE()+STRATEGIE) # effectifs par classe retenu après over et under sampling
dfs.rename({'Unnamed: 0':'Categorie'},axis=1,inplace=True)
df_resume=dfs.merge(dfp,on='Categorie',how='inner')
df_resume.drop('Unnamed: 0',axis=1,inplace=True)
df_resume.head(27)
# Out:
#     Categorie  Qunatity  predict     pourc  predict2    pourc2  predict3  \
# 0        1560      4000     1560  0.653000      2582  0.086000      2060
# 1        1300      4000     1300  0.827000      1280  0.041000      2585
# 2        2583      4000     2583  0.836000      2585  0.027000      2582
# 3        2060      3994     2060  0.527528      1560  0.093093      1920
# 4        2522      3991     2522  0.745491      1560  0.031062      2585
# 5        1280      3896     1280  0.393224      1300  0.187885      1140
# 6        2403      3819     2403  0.638743      2280  0.156021        10
# 7        2280      3808     2280  0.813025      2403  0.072479        10
# 8        1920      3442     1920  0.829268      1560  0.051103      2060
# 9        1160      3162     1160  0.916561      1281  0.020228      2462
# 10       1320      2593     1320  0.583333      1560  0.074074      1280
# 11         10      2493       10  0.492777      2705  0.174960      2280
# 12       2705      2209     2705  0.568841        10  0.271739      2905
# 13       1140      2137     1140  0.674157      1280  0.074906      1281
# 14       2582      2071     2582  0.482625      1560  0.175676      2060
# 15         40      2006       40  0.388446      2905  0.181275      2280
# 16       2585      2000     2585  0.543086      1300  0.082164      2583
# 17       1302      2000     1302  0.530120      1300  0.060241      1280
# 18       1281      2000     1281  0.350242      1280  0.157005      2522
# 19         50      2000       50  0.482143      1300  0.122024      2462
# 20       2462      2000     2462  0.686620        40  0.056338        50
# 21       2905      2000     2905  0.758621      2705  0.068966      2280
# 22         60      2000       60  0.813253      2462  0.048193        50
# 23       2220      2000     2220  0.466667      1560  0.084848      2583
# 24       1301      2000     1301  0.683230      1300  0.037267      2522
# 25       1940      2000     1940  0.751553      2522  0.043478      2583
# 26       1180      2000     1180  0.431373      1281  0.098039      1280
#
#       pourc3
# 0   0.080000
# 1   0.023000
# 2   0.021000
# 3   0.065065
# 4   0.022044
# 5   0.068789
# 6   0.068063
# 7   0.063025
# 8   0.034843
# 9   0.013906
# 10  0.069444
# 11  0.168539
# 12  0.050725
# 13  0.024345
# 14  0.075290
# 15  0.063745
# 16  0.080160
# 17  0.060241
# 18  0.050725
# 19  0.053571
# 20  0.038732
# 21  0.045977
# 22  0.036145
# 23  0.072727
# 24  0.037267
# 25  0.024845
# 26  0.078431

# %% [markdown]
# ### d) matrice de confusion

# %%
with open(testoriginal, 'rb') as f:
    y_test_original2 = pickle.load(f)
with open(predoriginal, 'rb') as f:
    test_pred_original2 = pickle.load(f)
with open(ds.get_RACINE_SAUVEGARDE() + 'y_train.pkl', 'rb') as f:
   y_train = pickle.load(f)
with open(ds.get_RACINE_SAUVEGARDE() + 'y_test.pkl', 'rb') as f:
    y_test = pickle.load(f)

# %%
import itertools # Pour créer des itérateurs
#cnf_matrix = confusion_matrix(y_test, test_pred_orinal,labels=[10,2280,2403,2705,40,50,2462,1280,1281])
cnf_matrix = confusion_matrix(y_test, test_pred_original2,labels=sorted(list(set(y_test_original2))))
#print(cnf_matrix)


classes=sorted(list(set(y_test_original2)))
b=list(set(y_test_original2))

plt.figure(figsize=(15,15))

plt.imshow(cnf_matrix, interpolation='nearest',cmap='Blues')
plt.title("Matrice de confusion")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes,rotation=90)
plt.yticks(tick_marks, classes)

for i, j in itertools.product(range(cnf_matrix.shape[0]), range(cnf_matrix.shape[1])):
    plt.text(j, i, cnf_matrix[i, j],
             horizontalalignment = "center",
             color = "white" if cnf_matrix[i, j] > ( cnf_matrix.max() / 2) else "black")

plt.ylabel('Vrais labels')
plt.xlabel('Labels prédits')
plt.show()

# %%
top5_df = pd.DataFrame({'prdtypecode': y_test_original2,'predict': test_pred_original2})
df_cross=pd.crosstab(top5_df['prdtypecode'], top5_df['predict'],normalize='index')
df_cross
# Out:
# predict          10        40        50        60        1140      1160  \
# prdtypecode
# 10           0.492777  0.009631  0.003210  0.000000  0.001605  0.009631
# 40           0.017928  0.388446  0.037849  0.009960  0.003984  0.039841
# 50           0.002976  0.026786  0.482143  0.029762  0.026786  0.005952
# 60           0.000000  0.018072  0.036145  0.813253  0.000000  0.000000
# 1140         0.009363  0.005618  0.007491  0.000000  0.674157  0.011236
# 1160         0.001264  0.003793  0.001264  0.000000  0.001264  0.916561
# 1180         0.013072  0.000000  0.000000  0.000000  0.039216  0.019608
# 1280         0.004107  0.007187  0.009240  0.003080  0.068789  0.004107
# 1281         0.016908  0.019324  0.021739  0.000000  0.028986  0.019324
# 1300         0.001000  0.004000  0.013000  0.003000  0.004000  0.001000
# 1301         0.006211  0.012422  0.006211  0.000000  0.000000  0.000000
# 1302         0.002008  0.000000  0.008032  0.002008  0.014056  0.004016
# 1320         0.001543  0.001543  0.009259  0.001543  0.013889  0.000000
# 2905         0.005747  0.011494  0.000000  0.022989  ...  0.000000  0.045977
#
# predict          2403      2462      2522      2582      2583      2585  \
# prdtypecode
# 10           0.080257  0.003210  0.019262  0.000000  0.000000  0.001605
# 40           0.029880  0.057769  0.009960  0.007968  0.009960  0.023904
# 50           0.011905  0.053571  0.041667  0.005952  0.029762  0.017857
# 60           0.000000  0.048193  0.024096  0.000000  0.000000  0.000000
# 1140         0.011236  0.022472  0.013109  0.011236  0.003745  0.003745
# 1160         0.011378  0.013906  0.002528  0.000000  0.000000  0.000000
# 1180         0.045752  0.045752  0.026144  0.006536  0.006536  0.000000
# 1280         0.010267  0.010267  0.019507  0.014374  0.013347  0.013347
# 1281         0.048309  0.031401  0.050725  0.014493  0.019324  0.004831
# 1300         0.004000  0.011000  0.012000  0.005000  0.017000  0.023000
# 1301         0.000000  0.018634  0.037267  0.012422  0.024845  0.031056
# 1302         0.002008  0.002008  0.044177  0.028112  0.028112  0.030120
# 1320         0.000000  0.003086  0.038580  0.020062  0.030864  0.010802
# 1560         0.000000  0.002000  0.020000  0.086000  0.014000  0.017000
# 1920         0.005807  0.001161  0.006969  0.012776  0.006969  0.006969
# 1940         0.006211  0.000000  0.043478  0.018634  0.024845  0.012422
# 2060         0.005005  0.000000  0.030030  0.049049  0.025025  0.040040
# 2220         0.000000  0.000000  0.060606  0.018182  0.072727  0.030303
# 2280         0.072479  0.006303  0.001050  0.000000  0.000000  0.000000
# 2403         0.638743  0.031414  0.014660  0.000000  0.002094  0.000000
# 2462         0.038732  0.686620  0.010563  0.000000  0.000000  0.000000
# 2522         0.019038  0.005010  0.745491  0.013026  0.020040  0.022044
# 2582         0.001931  0.003861  0.023166  0.482625  0.028958  0.065637
# 2583         0.000000  0.004000  0.018000  0.021000  0.836000  0.027000
# 2585         0.000000  0.006012  0.046092  0.040080  0.080160  0.543086
# 2705         0.039855  0.001812  0.001812  0.000000  0.000000  0.000000
# 2905         0.011494  0.005747  0.000000  0.000000  0.005747  0.000000
#
# predict          2705      2905
# prdtypecode
# 10           0.174960  0.017657
# 40           0.009960  0.181275
# 50           0.002976  0.002976
# 60           0.000000  0.000000
# 1140         0.007491  0.016854
# 1160         0.003793  0.001264
# 1180         0.006536  0.032680
# 1280         0.000000  0.003080
# 1281         0.002415  0.026570
# 1300         0.001000  0.001000
# 1301         0.006211  0.000000
# 1302         0.002008  0.002008
# 1320         0.000000  0.000000
# 1560         0.002000  0.000000
# 1920         0.000000  0.001161
# 1940         0.012422  0.000000
# 2060         0.006006  0.002002
# 2220         0.006061  0.000000
# 2280         0.013655  0.007353
# 2403         0.030366  0.007330
# 2462         0.003521  0.028169
# 2522         0.009018  0.002004
# 2582         0.001931  0.000000
# 2583         0.000000  0.000000
# 2585         0.000000  0.000000
# 2705         0.568841  0.050725
# 2905         0.068966  0.758621
#
# [27 rows x 27 columns]

# %% [markdown]
# ### e) Rapport de classification

# %%
# On évalue le niveau de précision de notre prédiction.
print("Précision de la prédiction:", accuracy_score(y_test_original2, test_pred_original2)*100, '%')

print("Evaluation détaillée de la Classification par RDF :\n \n" ,
      (classification_report(y_test_original2, test_pred_original2)))
# Out:
# Précision de la prédiction: 64.54956652845834 %
# Evaluation détaillée de la Classification par RDF :
#
#                precision    recall  f1-score   support
#
#           10       0.48      0.49      0.49       623
#           40       0.70      0.39      0.50       502
#           50       0.56      0.48      0.52       336
#           60       0.80      0.81      0.81       166
#         1140       0.72      0.67      0.70       534
#         1160       0.90      0.92      0.91       791
#         1180       0.60      0.43      0.50       153
#         1280       0.52      0.39      0.45       974
#         1281       0.41      0.35      0.38       414
#         1300       0.64      0.83      0.72      1000
#         1301       0.75      0.68      0.71       161
#         1302       0.60      0.53      0.56       498
#         1320       0.63      0.58      0.61       648
#         1560       0.59      0.65      0.62      1000
#         1920       0.81      0.83      0.82       861
#         1940       0.65      0.75      0.70       161
#         2060       0.61      0.53      0.57       999
#         2220       0.54      0.47      0.50       165
#         2280       0.67      0.81      0.74       952
#         2403       0.70      0.64      0.67       955
#         2462       0.52      0.69      0.59       284
#         2522       0.71      0.75      0.73       998
#         2582       0.48      0.48      0.48       518
#         2583       0.78      0.84      0.81      1000
#         2585       0.53      0.54      0.54       499
#         2705       0.61      0.57      0.59       552
#         2905       0.41      0.76      0.53       174
#
#     accuracy                           0.65     15918
#    macro avg       0.63      0.62      0.62     15918
# weighted avg       0.64      0.65      0.64     15918

# %% [markdown]
# ### f) Résumé de la classification obtenue

# %%
df_pred = pd.DataFrame()
for c in Lcat:
    print(c, '   ------   ', catdict[c])
    s = df_cross.loc[c].sort_values(ascending=False)[:5]
    df_temp = pd.DataFrame([{'Categorie':c,'predict':s.index[0],'pourc':s.values[0],'predict2':s.index[1],'pourc2':s.values[1],'predict3':s.index[2],'pourc3':s.values[2]}])
    df_pred = pd.concat([df_pred, df_temp], ignore_index=True)
    for index, value in s.items():  # Change ici
        print(f"  : {index},  : {np.round(value*100,2)} % , {catdict[index]}")
# Out:
# 10    ------    livres
#   : 10,  : 49.28 % , livres
#   : 2705,  : 17.5 % , bds et livres
#   : 2280,  : 16.85 % , magazines
#   : 2403,  : 8.03 % , livres et bds
#   : 2522,  : 1.93 % , produits de papeterie et rangement bureau
# 40    ------    jeux video pour pc et consoles
#   : 40,  : 38.84 % , jeux video pour pc et consoles
#   : 2905,  : 18.13 % , Jeu En téléchargement
#   : 2280,  : 6.37 % , magazines
#   : 2462,  : 5.78 % , consoles de jeux video et jeux videos
#   : 1160,  : 3.98 % , cartes collectionables
# 50    ------     accesoires jeux video
#   : 50,  : 48.21 % ,  accesoires jeux video
#   : 1300,  : 12.2 % , Petites voitures (jouets) et maquettes
#   : 2462,  : 5.36 % , consoles de jeux video et jeux videos
#   : 1560,  : 4.76 % , Mobilier et produits decoration/rangement pour la maison
#   : 2522,  : 4.17 % , produits de papeterie et rangement bureau
# 60    ------    consoles de jeux video
#   : 60,  : 81.33 % , consoles de jeux video
#   : 2462,  : 4.82 % , consoles de jeux video et jeux videos
#   : 50,  : 3.61 % ,  accesoires jeux video
#   : 1300,  : 3.01 % , Petites voitures (jouets) et maquettes
obilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 2582,  : 48.26 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 1560,  : 17.57 % , Mobilier et produits decoration/rangement pour la maison
#   : 2060,  : 7.53 % , lampes et accesoires decoration pour maison
#   : 2585,  : 6.56 % , outillage et accesoires pour jardinage
#   : 1300,  : 4.25 % , Petites voitures (jouets) et maquettes
# 2583    ------    accesoires de piscine
#   : 2583,  : 83.6 % , accesoires de piscine
#   : 2585,  : 2.7 % , outillage et accesoires pour jardinage
#   : 2582,  : 2.1 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 1560,  : 1.8 % , Mobilier et produits decoration/rangement pour la maison
#   : 2522,  : 1.8 % , produits de papeterie et rangement bureau
# 2585    ------    outillage et accesoires pour jardinage
#   : 2585,  : 54.31 % , outillage et accesoires pour jardinage
#   : 1300,  : 8.22 % , Petites voitures (jouets) et maquettes
#   : 2583,  : 8.02 % , accesoires de piscine
#   : 1560,  : 5.01 % , Mobilier et produits decoration/rangement pour la maison
#   : 2522,  : 4.61 % , produits de papeterie et rangement bureau
# 2705    ------    bds et livres
#   : 2705,  : 56.88 % , bds et livres
#   : 10,  : 27.17 % , livres
#   : 2905,  : 5.07 % , Jeu En téléchargement
#   : 2280,  : 4.17 % , magazines
#   : 2403,  : 3.99 % , livres et bds
# 2905    ------    Jeu En téléchargement
#   : 2905,  : 75.86 % , Jeu En téléchargement
#   : 2705,  : 6.9 % , bds et livres
#   : 2280,  : 4.6 % , magazines
#   : 40,  : 2.87 % , jeux video pour pc et consoles
#   : 1300,  : 2.3 % , Petites voitures (jouets) et maquettes

# %% [markdown]
# # I) Recherche du meilleur modèle
# ## test sur : optimizer, lrate, nb neuronnes, dropout
# ### a) premier type

# %% [markdown]
#             model = Sequential()
#             model.add(base_model) # Ajout du modèle  EfficientNetB1
#             model.add(Flatten())
#             model.add(Dropout(dprout))
#             model.add(Dense(niv1, activation='relu'))
#             model.add(BatchNormalization())
#             model.add(Dense(niv1//2, activation='relu'))
#             model.add(Dropout(dprout))
#             model.add(Dense(27, activation='softmax'))

# %%
chemin_du_fichier = ds.get_RACINE_SAUVEGARDE() +'param_grid_'+SUFFIXE_FICHIER+'.csv'
noms_de_colonnes = ['Modele','Lrate', 'NbNeurones_Layer1', 'NbNeurones_Layer2','Dropout','Accuracy','Loss','Val_accuracy','Val_loss']

df_reseaux = pd.DataFrame(columns=noms_de_colonnes)    
# Vérifiez si le fichier existe
if os.path.isfile(chemin_du_fichier):
    # Le fichier existe, le lire
    df_reseaux = pd.read_csv(chemin_du_fichier)
    print("Fichier existant lu avec succès.")
    print(df_reseaux['Lrate'].value_counts())
    print(df_reseaux['NbNeurones_Layer1'].value_counts())
    print(df_reseaux['Dropout'].value_counts())
else:
    # Le fichier n'existe pas, créer un nouveau DataFrame et le sauvegarder
    df_reseaux = pd.DataFrame(columns=noms_de_colonnes)

# %%
df_reseaux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Modele             0 non-null      object
#  1   Lrate              0 non-null      object
#  2   NbNeurones_Layer1  0 non-null      object
#  3   NbNeurones_Layer2  0 non-null      object
#  4   Dropout            0 non-null      object
#  5   Accuracy           0 non-null      object
#  6   Loss               0 non-null      object
#  7   Val_accuracy       0 non-null      object
#  8   Val_loss           0 non-null      object
# dtypes: object(9)
# memory usage: 124.0+ bytes

# %%
df_reseaux = df_reseaux.drop('Unnamed: 0', axis=1)

df_reseaux[['Modele','Lrate', 'NbNeurones_Layer1', 'Dropout']].head()
# Out:
#   Modele    Lrate  NbNeurones_Layer1  Dropout
# 0   Adam  0.00001               1024      0.2
# 1    SGD  0.00001               1024      0.2
# 2   Adam  0.00001               1024      0.3
# 3    SGD  0.00001               1024      0.3
# 4   Adam  0.00001               1024      0.4

# %%
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Conv2D, MaxPooling2D, BatchNormalization, LeakyReLU, Flatten
from tensorflow.keras.models import Model, Sequential, load_model


#for lrate in  [1e-5,5e-6,1e-6]:
for lrate in  [5e-4,1e-5,]:    
    for niv1 in [1024,512,128]:   
        for dprout in [0.20,0.30,0.40]:
            print("=====================  Adam   ============================")
            print("=====================  categorical_crossentropy   ============================")
            print('lrate = ' ,lrate)
            print('niv1 = ' ,niv1,niv1//2)
            print('dprout = ' ,dprout)
            condition = (
                (df_reseaux['Modele'] == 'Adam') &
                (df_reseaux['Lrate'] == lrate) &
                (df_reseaux['NbNeurones_Layer1'] == niv1) &
                (df_reseaux['Dropout'] == dprout)
            )
            on_execute = True
            if df_reseaux[condition].any().any():
                print("On passe")
                on_execute = False
            model = Sequential()
            model.add(base_model) # Ajout du modèle  RESNET50
            model.add(Flatten())
            model.add(Dropout(dprout))
            model.add(Dense(niv1, activation='relu'))
            model.add(BatchNormalization())
            model.add(Dense(niv1//2, activation='relu'))
            model.add(Dropout(dprout))
            model.add(Dense(27, activation='softmax'))
            if on_execute :
                model.compile(optimizer=Adam(learning_rate=lrate), loss='categorical_crossentropy', metrics=['accuracy'])
                #print(model.summary())
                training_history = model.fit(dataset_train, epochs=3, validation_data = dataset_test)
                train_acc = training_history.history['accuracy']
                val_acc = training_history.history['val_accuracy']
                tloss = training_history.history['loss']
                tvalloss=training_history.history['val_loss']
                df_reseaux.loc[len(df_reseaux)] = ['Adam',lrate, niv1,niv1//2, dprout,train_acc,tloss,val_acc,tvalloss]
                print(type(df_reseaux))
                print('Adam',lrate, niv1, dprout,train_acc,tloss,val_acc,tvalloss)
                #df_reseaux = df_reseaux.append({'Modele': 'Adam', 'Lrate': lrate, 'NbNeurones_Layer1': niv1,
                #        'NbNeurones_Layer2': niv1//2, 'Dropout': dprout, 'TrainAcc': train_acc, 'Tloss': tloss,
                #        'ValAcc': val_acc, 'Tvalloss': tvalloss})
                df_reseaux.to_csv( chemin_du_fichier)       
                #del training_history
                #gc.collect()
                print("=========================================================")
                print(df_reseaux)
df_reseaux.to_csv( chemin_du_fichier)
# Out:
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  0.0005
# niv1 =  1024 512
# dprout =  0.2
# Epoch 1/3
# 4670/4670 [==============================] - 1587s 340ms/step - loss: 2.3480 - accuracy: 0.3269 - val_loss: 99.0074 - val_accuracy: 0.4470
# Epoch 2/3
# 4670/4670 [==============================] - 1587s 340ms/step - loss: 1.8701 - accuracy: 0.4530 - val_loss: 81.8663 - val_accuracy: 0.4617
# Epoch 3/3
# 4670/4670 [==============================] - 1591s 341ms/step - loss: 1.6822 - accuracy: 0.5029 - val_loss: 188.8943 - val_accuracy: 0.4775
# <class 'pandas.core.frame.DataFrame'>
# Adam 0.0005 1024 0.2 [0.3269089162349701, 0.4529746472835541, 0.5029244422912598] [2.3479812145233154, 1.8700629472732544, 1.6822267770767212] [0.4470089375972748, 0.46166980266571045, 0.4775082468986511] [99.0074462890625, 81.86626434326172, 188.89431762695312]
# =========================================================
#   Modele   Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0   Adam  0.0005               1024                512      0.2
#
#                                             Accuracy  \
# 0  [0.3269089162349701, 0.4529746472835541, 0.502...
#
#                                                 Loss  \
# 0  [2.3479812145233154, 1.8700629472732544, 1.682...
#
#                                         Val_accuracy  \
# 0  [0.4470089375972748, 0.46166980266571045, 0.47...
#
#                                             Val_loss
# 0  [99.0074462890625, 81.86626434326172, 188.8943...
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  0.0005
# niv1 =  1024 512
# dprout =  0.3
# Epoch 1/3
# 4670/4670 [==============================] - 1590s 340ms/step - loss: 1.8466 - accuracy: 0.4717 - val_loss: 253.7093 - val_accuracy: 0.4962
# Epoch 2/3
# 4670/4670 [==============================] - 1585s 339ms/step - loss: 1.5994 - accuracy: 0.5284 - val_loss: 4.6861 - val_accuracy: 0.5233
# Epoch 3/3
# 4670/4670 [==============================] - 1628s 349ms/step - loss: 1.5261 - accuracy: 0.5461 - val_loss: 87.8216 - val_accuracy: 0.5187
# <class 'pandas.core.frame.DataFrame'>
# Adam 0.0005 1024 0.3 [0.4716723561286926, 0.528367817401886, 0.5460751056671143] [1.84661865234375, 1.5993729829788208, 1.5261061191558838] [0.49617287516593933, 0.5232571959495544, 0.5187234878540039] [253.70932006835938, 4.686125755310059, 87.82160186767578]
# =========================================================
#   Modele   Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0   Adam  0.0005               1024                512      0.2
# 1   Adam  0.0005               1024                512      0.3
#
#                                             Accuracy  \
# 0  [0.3269089162349701, 0.4529746472835541, 0.502...
# 1  [0.4716723561286926, 0.528367817401886, 0.5460...
#
#                                                 Loss  \
# 0  [2.3479812145233154, 1.8700629472732544, 1.682...
# 1  [1.84661865234375, 1.5993729829788208, 1.52610...
#
#                                         Val_accuracy  \
# 0  [0.4470089375972748, 0.46166980266571045, 0.47...
# 1  [0.49617287516593933, 0.5232571959495544, 0.51...
#
#                                             Val_loss
# 0  [99.0074462890625, 81.86626434326172, 188.8943...
# 1  [253.70932006835938, 4.686125755310059, 87.821...
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  0.0005
# niv1 =  1024 512
# dprout =  0.4
# Epoch 1/3
# 4670/4670 [==============================] - 1658s 355ms/step - loss: 1.7651 - accuracy: 0.4972 - val_loss: 1.7383 - val_accuracy: 0.5088
# Epoch 2/3
# 4670/4670 [==============================] - 1665s 357ms/step - loss: 1.5389 - accuracy: 0.5469 - val_loss: 133.2445 - val_accuracy: 0.5310
# Epoch 3/3
# 4670/4670 [==============================] - 1627s 348ms/step - loss: 1.4681 - accuracy: 0.5642 - val_loss: 25.4082 - val_accuracy: 0.5244
# <class 'pandas.core.frame.DataFrame'>
# Adam 0.0005 1024 0.4 [0.4972093999385834, 0.5469182729721069, 0.5641705393791199] [1.7650712728500366, 1.5388569831848145, 1.4680625200271606] [0.5088318586349487, 0.531029224395752, 0.524375855922699] [1.7382745742797852, 133.24447631835938, 25.408248901367188]
# =========================================================
#   Modele   Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0   Adam  0.0005               1024                512      0.2
# 1   Adam  0.0005               1024                512      0.3
# 2   Adam  0.0005               1024                512      0.4
#
#                                             Accuracy  \
# 0  [0.3269089162349701, 0.4529746472835541, 0.502...
# 1  [0.4716723561286926, 0.528367817401886, 0.5460...
# 2  [0.4972093999385834, 0.5469182729721069, 0.564...
#
#                                                 Loss  \
# 0  [2.3479812145233154, 1.8700629472732544, 1.682...
# 1  [1.84661865234375, 1.5993729829788208, 1.52610...
# 2  [1.7650712728500366, 1.5388569831848145, 1.468...
#
#                                         Val_accuracy  \
# 0  [0.4470089375972748, 0.46166980266571045, 0.47...
# 1  [0.49617287516593933, 0.5232571959495544, 0.51...
# 2  [0.5088318586349487, 0.531029224395752, 0.5243...
#
#                                             Val_loss
# 0  [99.0074462890625, 81.86626434326172, 188.8943...
# 1  [253.70932006835938, 4.686125755310059, 87.821...
# 2  [1.7382745742797852, 133.24447631835938, 25.40...
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  0.0005
# niv1 =  512 256
# dprout =  0.2
# Epoch 1/3
# 4670/4670 [==============================] - 1591s 340ms/step - loss: 1.5115 - accuracy: 0.5579 - val_loss: 1.5865 - val_accuracy: 0.5561
# Epoch 2/3
# 4670/4670 [==============================] - 1573s 337ms/step - loss: 1.3480 - accuracy: 0.5969 - val_loss: 5.9776 - val_accuracy: 0.5433
# Epoch 3/3
# 4670/4670 [==============================] - 1567s 336ms/step - loss: 1.2574 - accuracy: 0.6197 - val_loss: 1.6858 - val_accuracy: 0.5470
# <class 'pandas.core.frame.DataFrame'>
# Adam 0.0005 512 0.2 [0.5579200983047485, 0.5969082713127136, 0.6197282671928406] [1.5115047693252563, 1.3480229377746582, 1.2574026584625244] [0.5561116337776184, 0.5432760119438171, 0.5470442771911621] [1.5864728689193726, 5.977613925933838, 1.6857575178146362]
# =========================================================
#   Modele   Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0   Adam  0.0005               1024                512      0.2
# 1   Adam  0.0005               1024                512      0.3
# 2   Adam  0.0005               1024                512      0.4
# 3   Adam  0.0005                512                256      0.2
#
#                                             Accuracy  \
# 0  [0.3269089162349701, 0.4529746472835541, 0.502...
# 1  [0.4716723561286926, 0.528367817401886, 0.5460...
# 2  [0.4972093999385834, 0.5469182729721069, 0.564...
# 3  [0.5579200983047485, 0.5969082713127136, 0.619...
#
#                                                 Loss  \
# 0  [2.3479812145233154, 1.8700629472732544, 1.682...
# 1  [1.84661865234375, 1.5993729829788208, 1.52610...
# 2  [1.7650712728500366, 1.5388569831848145, 1.468...
# 3  [1.5115047693252563, 1.3480229377746582, 1.257...
#
#                                         Val_accuracy  \
# 0  [0.4470089375972748, 0.46166980266571045, 0.47...
# 1  [0.49617287516593933, 0.5232571959495544, 0.51...
# 2  [0.5088318586349487, 0.531029224395752, 0.5243...
# 3  [0.5561116337776184, 0.5432760119438171, 0.547...
#
#                                             Val_loss
# 0  [99.0074462890625, 81.86626434326172, 188.8943...
# 1  [253.70932006835938, 4.686125755310059, 87.821...
# 2  [1.7382745742797852, 133.24447631835938, 25.40...
# 3  [1.5864728689193726, 5.977613925933838, 1.6857...
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  0.0005
# niv1 =  512 256
# dprout =  0.3
# Epoch 1/3
# 4670/4670 [==============================] - 1560s 334ms/step - loss: 1.4107 - accuracy: 0.5864 - val_loss: 541.1002 - val_accuracy: 0.5543
# Epoch 2/3
# 4670/4670 [==============================] - 1555s 333ms/step - loss: 1.2432 - accuracy: 0.6285 - val_loss: 1.9434 - val_accuracy: 0.5546
# Epoch 3/3
# 4670/4670 [==============================] - 1555s 333ms/step - loss: 1.1794 - accuracy: 0.6450 - val_loss: 1.5274 - val_accuracy: 0.5677
# <class 'pandas.core.frame.DataFrame'>
# Adam 0.0005 512 0.3 [0.586401641368866, 0.6285216808319092, 0.645037829875946] [1.4107152223587036, 1.2431749105453491, 1.1793632507324219] [0.5543452501296997, 0.5546396374702454, 0.5676519274711609] [541.1002197265625, 1.943395972251892, 1.5274049043655396]
# =========================================================
#   Modele   Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0   Adam  0.0005               1024                512      0.2
# 1   Adam  0.0005               1024                512      0.3
# 2   Adam  0.0005               1024                512      0.4
# 3   Adam  0.0005                512                256      0.2
# 4   Adam  0.0005                512                256      0.3
#
#                                             Accuracy  \
# 0  [0.3269089162349701, 0.4529746472835541, 0.502...
# 1  [0.4716723561286926, 0.528367817401886, 0.5460...
# 2  [0.4972093999385834, 0.5469182729721069, 0.564...
# 3  [0.5579200983047485, 0.5969082713127136, 0.619...
# 4  [0.586401641368866, 0.6285216808319092, 0.6450...
#
#                                                 Loss  \
# 0  [2.3479812145233154, 1.8700629472732544, 1.682...
# 1  [1.84661865234375, 1.5993729829788208, 1.52610...
# 2  [1.7650712728500366, 1.5388569831848145, 1.468...
# 3  [1.5115047693252563, 1.3480229377746582, 1.257...
# 4  [1.4107152223587036, 1.2431749105453491, 1.179...
#
#                                         Val_accuracy  \
# 0  [0.4470089375972748, 0.46166980266571045, 0.47...
# 1  [0.49617287516593933, 0.5232571959495544, 0.51...
# 2  [0.5088318586349487, 0.531029224395752, 0.5243...
# 3  [0.5561116337776184, 0.5432760119438171, 0.547...
# 4  [0.5543452501296997, 0.5546396374702454, 0.567...
#
#                                             Val_loss
# 0  [99.0074462890625, 81.86626434326172, 188.8943...
# 1  [253.70932006835938, 4.686125755310059, 87.821...
# 2  [1.7382745742797852, 133.24447631835938, 25.40...
# 3  [1.5864728689193726, 5.977613925933838, 1.6857...
# 4  [541.1002197265625, 1.943395972251892, 1.52740...
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  0.0005
# niv1 =  512 256
# dprout =  0.4
# Epoch 1/3
# 4670/4670 [==============================] - 1558s 333ms/step - loss: 1.3334 - accuracy: 0.6119 - val_loss: 1.5534 - val_accuracy: 0.5584
# Epoch 2/3
# 4670/4670 [==============================] - 1557s 333ms/step - loss: 1.1763 - accuracy: 0.6499 - val_loss: 1.5037 - val_accuracy: 0.5750
# Epoch 3/3
# 4670/4670 [==============================] - 1557s 333ms/step - loss: 1.1138 - accuracy: 0.6665 - val_loss: 1.5073 - val_accuracy: 0.5665
# <class 'pandas.core.frame.DataFrame'>
# Adam 0.0005 512 0.4 [0.611911952495575, 0.6499230265617371, 0.6665328145027161] [1.333390235900879, 1.1762731075286865, 1.1137733459472656] [0.5584079027175903, 0.5749529004096985, 0.5664743185043335] [1.553402066230774, 1.503735899925232, 1.5072799921035767]
# =========================================================
#   Modele   Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0   Adam  0.0005               1024                512      0.2
# 1   Adam  0.0005               1024                512      0.3
# 2   Adam  0.0005               1024                512      0.4
# 3   Adam  0.0005                512                256      0.2
# 4   Adam  0.0005                512                256      0.3
# 5   Adam  0.0005                512                256      0.4
#
#                                             Accuracy  \
# 0  [0.3269089162349701, 0.4529746472835541, 0.502...
# 1  [0.4716723561286926, 0.528367817401886, 0.5460...
# 2  [0.4972093999385834, 0.5469182729721069, 0.564...
# 3  [0.5579200983047485, 0.5969082713127136, 0.619...
# 4  [0.586401641368866, 0.6285216808319092, 0.6450...
# 5  [0.611911952495575, 0.6499230265617371, 0.6665...
#
#                                                 Loss  \
# 0  [2.3479812145233154, 1.8700629472732544, 1.682...
# 1  [1.84661865234375, 1.5993729829788208, 1.52610...
# 2  [1.7650712728500366, 1.5388569831848145, 1.468...
# 3  [1.5115047693252563, 1.3480229377746582, 1.257...
# 4  [1.4107152223587036, 1.2431749105453491, 1.179...
# 5  [1.333390235900879, 1.1762731075286865, 1.1137...
#
#                                         Val_accuracy  \
# 0  [0.4470089375972748, 0.46166980266571045, 0.47...
# 1  [0.49617287516593933, 0.5232571959495544, 0.51...
# 2  [0.5088318586349487, 0.531029224395752, 0.5243...
# 3  [0.5561116337776184, 0.5432760119438171, 0.547...
# 4  [0.5543452501296997, 0.5546396374702454, 0.567...
# 5  [0.5584079027175903, 0.5749529004096985, 0.566...
#
#                                             Val_loss
# 0  [99.0074462890625, 81.86626434326172, 188.8943...
# 1  [253.70932006835938, 4.686125755310059, 87.821...
# 2  [1.7382745742797852, 133.24447631835938, 25.40...
# 3  [1.5864728689193726, 5.977613925933838, 1.6857...
# 4  [541.1002197265625, 1.943395972251892, 1.52740...
# 5  [1.553402066230774, 1.503735899925232, 1.50727...
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  0.0005
# niv1 =  128 64
# dprout =  0.2
# Epoch 1/3
# 4670/4670 [==============================] - 1541s 330ms/step - loss: 1.2417 - accuracy: 0.6378 - val_loss: 5.1741 - val_accuracy: 0.5834
# Epoch 2/3
# 4670/4670 [==============================] - 1540s 330ms/step - loss: 1.0718 - accuracy: 0.6794 - val_loss: 1.4689 - val_accuracy: 0.5904
# Epoch 3/3
# 4670/4670 [==============================] - 1540s 330ms/step - loss: 1.0111 - accuracy: 0.6933 - val_loss: 1.4519 - val_accuracy: 0.5870
# <class 'pandas.core.frame.DataFrame'>
# Adam 0.0005 128 0.2 [0.6378371119499207, 0.6793950200080872, 0.6932744383811951] [1.2416951656341553, 1.0718423128128052, 1.0111253261566162] [0.5834314823150635, 0.5904380679130554, 0.5870230793952942] [5.174145221710205, 1.4689007997512817, 1.4518911838531494]
# =========================================================
#   Modele   Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0   Adam  0.0005               1024                512      0.2
# 1   Adam  0.0005               1024                512      0.3
# 2   Adam  0.0005               1024                512      0.4
# 3   Adam  0.0005                512                256      0.2
# 4   Adam  0.0005                512                256      0.3
# 5   Adam  0.0005                512                256      0.4
# 6   Adam  0.0005                128                 64      0.2
#
#                                             Accuracy  \
# 0  [0.3269089162349701, 0.4529746472835541, 0.502...
# 1  [0.4716723561286926, 0.528367817401886, 0.5460...
# 2  [0.4972093999385834, 0.5469182729721069, 0.564...
# 3  [0.5579200983047485, 0.5969082713127136, 0.619...
# 4  [0.586401641368866, 0.6285216808319092, 0.6450...
# 5  [0.611911952495575, 0.6499230265617371, 0.6665...
# 6  [0.6378371119499207, 0.6793950200080872, 0.693...
#
#                                                 Loss  \
# 0  [2.3479812145233154, 1.8700629472732544, 1.682...
# 1  [1.84661865234375, 1.5993729829788208, 1.52610...
# 2  [1.7650712728500366, 1.5388569831848145, 1.468...
# 3  [1.5115047693252563, 1.3480229377746582, 1.257...
# 4  [1.4107152223587036, 1.2431749105453491, 1.179...
# 5  [1.333390235900879, 1.1762731075286865, 1.1137...
# 6  [1.2416951656341553, 1.0718423128128052, 1.011...
#
#                                         Val_accuracy  \
# 0  [0.4470089375972748, 0.46166980266571045, 0.47...
# 1  [0.49617287516593933, 0.5232571959495544, 0.51...
# 2  [0.5088318586349487, 0.531029224395752, 0.5243...
# 3  [0.5561116337776184, 0.5432760119438171, 0.547...
# 4  [0.5543452501296997, 0.5546396374702454, 0.567...
# 5  [0.5584079027175903, 0.5749529004096985, 0.566...
# 6  [0.5834314823150635, 0.5904380679130554, 0.587...
#
#                                             Val_loss
# 0  [99.0074462890625, 81.86626434326172, 188.8943...
# 1  [253.70932006835938, 4.686125755310059, 87.821...
# 2  [1.7382745742797852, 133.24447631835938, 25.40...
# 3  [1.5864728689193726, 5.977613925933838, 1.6857...
# 4  [541.1002197265625, 1.943395972251892, 1.52740...
# 5  [1.553402066230774, 1.503735899925232, 1.50727...
# 6  [5.174145221710205, 1.4689007997512817, 1.4518...
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  0.0005
# niv1 =  128 64
# dprout =  0.3
# Epoch 1/3
# 4670/4670 [==============================] - 1543s 330ms/step - loss: 1.1889 - accuracy: 0.6583 - val_loss: 1.4993 - val_accuracy: 0.5841
# Epoch 2/3
# 4670/4670 [==============================] - 1542s 330ms/step - loss: 1.0303 - accuracy: 0.6955 - val_loss: 1.5471 - val_accuracy: 0.5721
# Epoch 3/3
# 4670/4670 [==============================] - 1543s 330ms/step - loss: 0.9805 - accuracy: 0.7086 - val_loss: 1.5395 - val_accuracy: 0.5785
# <class 'pandas.core.frame.DataFrame'>
# Adam 0.0005 128 0.3 [0.6583015322685242, 0.6954694390296936, 0.7086395025253296] [1.1888597011566162, 1.030273675918579, 0.9805101156234741] [0.5840791463851929, 0.5721266865730286, 0.5784856081008911] [1.4992742538452148, 1.5470725297927856, 1.5395320653915405]
# =========================================================
#   Modele   Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0   Adam  0.0005               1024                512      0.2
# 1   Adam  0.0005               1024                512      0.3
# 2   Adam  0.0005               1024                512      0.4
# 3   Adam  0.0005                512                256      0.2
# 4   Adam  0.0005                512                256      0.3
# 5   Adam  0.0005                512                256      0.4
# 6   Adam  0.0005                128                 64      0.2
# 7   Adam  0.0005                128                 64      0.3
#
#                                             Accuracy  \
# 0  [0.3269089162349701, 0.4529746472835541, 0.502...
# 1  [0.4716723561286926, 0.528367817401886, 0.5460...
# 2  [0.4972093999385834, 0.5469182729721069, 0.564...
# 3  [0.5579200983047485, 0.5969082713127136, 0.619...
# 4  [0.586401641368866, 0.6285216808319092, 0.6450...
# 5  [0.611911952495575, 0.6499230265617371, 0.6665...
# 6  [0.6378371119499207, 0.6793950200080872, 0.693...
# 7  [0.6583015322685242, 0.6954694390296936, 0.708...
#
#                                                 Loss  \
# 0  [2.3479812145233154, 1.8700629472732544, 1.682...
# 1  [1.84661865234375, 1.5993729829788208, 1.52610...
# 2  [1.7650712728500366, 1.5388569831848145, 1.468...
# 3  [1.5115047693252563, 1.3480229377746582, 1.257...
# 4  [1.4107152223587036, 1.2431749105453491, 1.179...
# 5  [1.333390235900879, 1.1762731075286865, 1.1137...
# 6  [1.2416951656341553, 1.0718423128128052, 1.011...
# 7  [1.1888597011566162, 1.030273675918579, 0.9805...
#
#                                         Val_accuracy  \
# 0  [0.4470089375972748, 0.46166980266571045, 0.47...
# 1  [0.49617287516593933, 0.5232571959495544, 0.51...
# 2  [0.5088318586349487, 0.531029224395752, 0.5243...
# 3  [0.5561116337776184, 0.5432760119438171, 0.547...
# 4  [0.5543452501296997, 0.5546396374702454, 0.567...
# 5  [0.5584079027175903, 0.5749529004096985, 0.566...
# 6  [0.5834314823150635, 0.5904380679130554, 0.587...
# 7  [0.5840791463851929, 0.5721266865730286, 0.578...
#
#                                             Val_loss
# 0  [99.0074462890625, 81.86626434326172, 188.8943...
# 1  [253.70932006835938, 4.686125755310059, 87.821...
# 2  [1.7382745742797852, 133.24447631835938, 25.40...
# 3  [1.5864728689193726, 5.977613925933838, 1.6857...
# 4  [541.1002197265625, 1.943395972251892, 1.52740...
# 5  [1.553402066230774, 1.503735899925232, 1.50727...
# 6  [5.174145221710205, 1.4689007997512817, 1.4518...
# 7  [1.4992742538452148, 1.5470725297927856, 1.539...
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  0.0005
# niv1 =  128 64
# dprout =  0.4
# Epoch 1/3
# 4670/4670 [==============================] - 1544s 330ms/step - loss: 1.1987 - accuracy: 0.6613 - val_loss: 1.5739 - val_accuracy: 0.5790
# Epoch 2/3
# 4670/4670 [==============================] - 1549s 332ms/step - loss: 1.0168 - accuracy: 0.7038 - val_loss: 1.5447 - val_accuracy: 0.5851
# Epoch 3/3
# 4670/4670 [==============================] - 1564s 335ms/step - loss: 0.9648 - accuracy: 0.7168 - val_loss: 1.7457 - val_accuracy: 0.5877
# <class 'pandas.core.frame.DataFrame'>
# Adam 0.0005 128 0.4 [0.661312997341156, 0.7038211822509766, 0.7167636752128601] [1.1987342834472656, 1.0167683362960815, 0.9648080468177795] [0.578956663608551, 0.5851389765739441, 0.5876707434654236] [1.5739414691925049, 1.5447273254394531, 1.7456642389297485]
# =========================================================
#   Modele   Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 

# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  1024 512
# dprout =  0.2
# Epoch 1/3
# 4670/4670 [==============================] - 1592s 341ms/step - loss: 0.9730 - accuracy: 0.7176 - val_loss: 1.5813 - val_accuracy: 0.6067
# Epoch 2/3
# 4670/4670 [==============================] - 1592s 341ms/step - loss: 0.7907 - accuracy: 0.7600 - val_loss: 1.5477 - val_accuracy: 0.6135
# Epoch 3/3
# 4670/4670 [==============================] - 1588s 340ms/step - loss: 0.7419 - accuracy: 0.7704 - val_loss: 1.5366 - val_accuracy: 0.6141
# <class 'pandas.core.frame.DataFrame'>
# Adam 1e-05 1024 0.2 [0.7176470756530762, 0.7599545121192932, 0.7704343199729919] [0.9730402827262878, 0.7906745672225952, 0.7418712377548218] [0.6067475080490112, 0.6135185956954956, 0.6141073703765869] [1.5812599658966064, 1.5477163791656494, 1.536620020866394]
# =========================================================
#   Modele    Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0   Adam  0.00050               1024                512      0.2
# 1   Adam  0.00050               1024                512      0.3
# 2   Adam  0.00050               1024                512      0.4
# 3   Adam  0.00050                512                256      0.2
# 4   Adam  0.00050                512                256      0.3
# 5   Adam  0.00050                512                256      0.4
# 6   Adam  0.00050                128                 64      0.2
# 7   Adam  0.00050                128                 64      0.3
# 8   Adam  0.00050                128                 64      0.4
# 9   Adam  0.00001               1024                512      0.2
#
#                                             Accuracy  \
# 0  [0.3269089162349701, 0.4529746472835541, 0.502...
# 1  [0.4716723561286926, 0.528367817401886, 0.5460...
# 2  [0.4972093999385834, 0.5469182729721069, 0.564...
# 3  [0.5579200983047485, 0.5969082713127136, 0.619...
# 4  [0.586401641368866, 0.6285216808319092, 0.6450...
# 5  [0.611911952495575, 0.6499230265617371, 0.6665...
# 6  [0.6378371119499207, 0.6793950200080872, 0.693...
# 7  [0.6583015322685242, 0.6954694390296936, 0.708...
# 8  [0.661312997341156, 0.7038211822509766, 0.7167...
# 9  [0.7176470756530762, 0.7599545121192932, 0.770...
#
#                                                 Loss  \
# 0  [2.3479812145233154, 1.8700629472732544, 1.682...
# 1  [1.84661865234375, 1.5993729829788208, 1.52610...
# 2  [1.7650712728500366, 1.5388569831848145, 1.468...
# 3  [1.5115047693252563, 1.3480229377746582, 1.257...
# 4  [1.4107152223587036, 1.2431749105453491, 1.179...
# 5  [1.333390235900879, 1.1762731075286865, 1.1137...
# 6  [1.2416951656341553, 1.0718423128128052, 1.011...
# 7  [1.1888597011566162, 1.030273675918579, 0.9805...
# 8  [1.1987342834472656, 1.0167683362960815, 0.964...
# 9  [0.9730402827262878, 0.7906745672225952, 0.741...
#
#                                         Val_accuracy  \
# 0  [0.4470089375972748, 0.46166980266571045, 0.47...
# 1  [0.49617287516593933, 0.5232571959495544, 0.51...
# 2  [0.5088318586349487, 0.531029224395752, 0.5243...
# 3  [0.5561116337776184, 0.5432760119438171, 0.547...
# 4  [0.5543452501296997, 0.5546396374702454, 0.567...
# 5  [0.5584079027175903, 0.5749529004096985, 0.566...
# 6  [0.5834314823150635, 0.5904380679130554, 0.587...
# 7  [0.5840791463851929, 0.5721266865730286, 0.578...
# 8  [0.578956663608551, 0.5851389765739441, 0.5876...
# 9  [0.6067475080490112, 0.6135185956954956, 0.614...
#
#                                             Val_loss
# 0  [99.0074462890625, 81.86626434326172, 188.8943...
# 1  [253.70932006835938, 4.686125755310059, 87.821...
# 2  [1.7382745742797852, 133.24447631835938, 25.40...
# 3  [1.5864728689193726, 5.977613925933838, 1.6857...
# 4  [541.1002197265625, 1.943395972251892, 1.52740...
# 5  [1.553402066230774, 1.503735899925232, 1.50727...
# 6  [5.174145221710205, 1.4689007997512817, 1.4518...
# 7  [1.4992742538452148, 1.5470725297927856, 1.539...
# 8  [1.5739414691925049, 1.5447273254394531, 1.745...
# 9  [1.5812599658966064, 1.5477163791656494, 1.536...
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  1024 512
# dprout =  0.3
# Epoch 1/3
# 4670/4670 [==============================] - 1625s 348ms/step - loss: 0.9745 - accuracy: 0.7200 - val_loss: 1.5631 - val_accuracy: 0.6126
# Epoch 2/3
# 4670/4670 [==============================] - 1747s 374ms/step - loss: 0.7853 - accuracy: 0.7625 - val_loss: 1.5399 - val_accuracy: 0.6128
# Epoch 3/3
# 4670/4670 [==============================] - 1815s 389ms/step - loss: 0.7495 - accuracy: 0.7701 - val_loss: 1.5366 - val_accuracy: 0.6131
# <class 'pandas.core.frame.DataFrame'>
# Adam 1e-05 1024 0.3 [0.7200428247451782, 0.7625108957290649, 0.7700729370117188] [0.9744589924812317, 0.7852530479431152, 0.7495176792144775] [0.6125765442848206, 0.61275315284729, 0.6131064295768738] [1.5631039142608643, 1.5398941040039062, 1.5365934371948242]
# =========================================================
#    Modele    Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0    Adam  0.00050               1024                512      0.2
# 1    Adam  0.00050               1024                512      0.3
# 2    Adam  0.00050               1024                512      0.4
# 3    Adam  0.00050                512                256      0.2
# 4    Adam  0.00050                512                256      0.3
# 5    Adam  0.00050                512                256      0.4
# 6    Adam  0.00050                128                 64      0.2
# 7    Adam  0.00050                128                 64      0.3
# 8    Adam  0.00050                128                 64      0.4
# 9    Adam  0.00001               1024                512      0.2
# 10   Adam  0.00001               1024                512      0.3
#
#                                              Accuracy  \
# 0   [0.3269089162349701, 0.4529746472835541, 0.502...
# 1   [0.4716723561286926, 0.528367817401886, 0.5460...
# 2   [0.4972093999385834, 0.5469182729721069, 0.564...
# 3   [0.5579200983047485, 0.5969082713127136, 0.619...
# 4   [0.586401641368866, 0.6285216808319092, 0.6450...
# 5   [0.611911952495575, 0.6499230265617371, 0.6665...
# 6   [0.6378371119499207, 0.6793950200080872, 0.693...
# 7   [0.6583015322685242, 0.6954694390296936, 0.708...
# 8   [0.661312997341156, 0.7038211822509766, 0.7167...
# 9   [0.7176470756530762, 0.7599545121192932, 0.770...
# 10  [0.7200428247451782, 0.7625108957290649, 0.770...
#
#                                                  Loss  \
# 0   [2.3479812145233154, 1.8700629472732544, 1.682...
# 1   [1.84661865234375, 1.5993729829788208, 1.52610...
# 2   [1.7650712728500366, 1.5388569831848145, 1.468...
# 3   [1.5115047693252563, 1.3480229377746582, 1.257...
# 4   [1.4107152223587036, 1.2431749105453491, 1.179...
# 5   [1.333390235900879, 1.1762731075286865, 1.1137...
# 6   [1.2416951656341553, 1.0718423128128052, 1.011...
# 7   [1.1888597011566162, 1.030273675918579, 0.9805...
# 8   [1.1987342834472656, 1.0167683362960815, 0.964...
# 9   [0.9730402827262878, 0.7906745672225952, 0.741...
# 10  [0.9744589924812317, 0.7852530479431152, 0.749...
#
#                                          Val_accuracy  \
# 0   [0.4470089375972748, 0.46166980266571045, 0.47...
# 1   [0.49617287516593933, 0.5232571959495544, 0.51...
# 2   [0.5088318586349487, 0.531029224395752, 0.5243...
# 3   [0.5561116337776184, 0.5432760119438171, 0.547...
# 4   [0.5543452501296997, 0.5546396374702454, 0.567...
# 5   [0.5584079027175903, 0.5749529004096985, 0.566...
# 6   [0.5834314823150635, 0.5904380679130554, 0.587...
# 7   [0.5840791463851929, 0.5721266865730286, 0.578...
# 8   [0.578956663608551, 0.5851389765739441, 0.5876...
# 9   [0.6067475080490112, 0.6135185956954956, 0.614...
# 10  [0.6125765442848206, 0.61275315284729, 0.61310...
#
#                                              Val_loss
# 0   [99.0074462890625, 81.86626434326172, 188.8943...
# 1   [253.70932006835938, 4.686125755310059, 87.821...
# 2   [1.7382745742797852, 133.24447631835938, 25.40...
# 3   [1.5864728689193726, 5.977613925933838, 1.6857...
# 4   [541.1002197265625, 1.943395972251892, 1.52740...
# 5   [1.553402066230774, 1.503735899925232, 1.50727...
# 6   [5.174145221710205, 1.4689007997512817, 1.4518...
# 7   [1.4992742538452148, 1.5470725297927856, 1.539...
# 8   [1.5739414691925049, 1.5447273254394531, 1.745...
# 9   [1.5812599658966064, 1.5477163791656494, 1.536...
# 10  [1.5631039142608643, 1.5398941040039062, 1.536...
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  1024 512
# dprout =  0.4
# Epoch 1/3
# 4670/4670 [==============================] - 1831s 392ms/step - loss: 1.0335 - accuracy: 0.7082 - val_loss: 1.5743 - val_accuracy: 0.6144
# Epoch 2/3
# 4670/4670 [==============================] - 1856s 397ms/step - loss: 0.8122 - accuracy: 0.7582 - val_loss: 1.5396 - val_accuracy: 0.6161
# Epoch 3/3
# 4670/4670 [==============================] - 1826s 391ms/step - loss: 0.7657 - accuracy: 0.7698 - val_loss: 1.5532 - val_accuracy: 0.6162
# <class 'pandas.core.frame.DataFrame'>
# Adam 1e-05 1024 0.4 [0.7082379460334778, 0.7581743597984314, 0.7698320150375366] [1.0335203409194946, 0.8121669292449951, 0.7657074332237244] [0.6144017577171326, 0.6160504221916199, 0.6162270307540894] [1.5743471384048462, 1.53955078125, 1.5532081127166748]
# =========================================================
#    Modele    Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0    Adam  0.00050               1024                512      0.2
# 1    Adam  0.00050               1024                512      0.3
# 2    Adam  0.00050               1024                512      0.4
# 3    Adam  0.00050                512                256      0.2
# 4    Adam  0.00050                512                256      0.3
# 5    Adam  0.00050                512                256      0.4
# 6    Adam  0.00050                128                 64      0.2
# 7    Adam  0.00050                128                 64      0.3
# 8    Adam  0.00050                128                 64      0.4
# 9    Adam  0.00001               1024                512      0.2
# 10   Adam  0.00001               1024                512      0.3
# 11   Adam  0.00001               1024                512      0.4
#
#                                              Accuracy  \
# 0   [0.3269089162349701, 0.4529746472835541, 0.502...
# 1   [0.4716723561286926, 0.528367817401886, 0.5460...
# 2   [0.4972093999385834, 0.5469182729721069, 0.564...
# 3   [0.5579200983047485, 0.5969082713127136, 0.619...
# 6   [0.5834314823150635, 0.5904380679130554, 0.587...
# 7   [0.5840791463851929, 0.5721266865730286, 0.578...
# 8   [0.578956663608551, 0.5851389765739441, 0.5876...
# 9   [0.6067475080490112, 0.6135185956954956, 0.614...
# 10  [0.6125765442848206, 0.61275315284729, 0.61310...
# 11  [0.6144017577171326, 0.6160504221916199, 0.616...
# 12  [0.6137540936470032, 0.6098092198371887, 0.613...
#
#                                              Val_loss
# 0   [99.0074462890625, 81.86626434326172, 188.8943...
# 1   [253.70932006835938, 4.686125755310059, 87.821...
# 2   [1.7382745742797852, 133.24447631835938, 25.40...
# 3   [1.5864728689193726, 5.977613925933838, 1.6857...
# 4   [541.1002197265625, 1.943395972251892, 1.52740...
# 5   [1.553402066230774, 1.503735899925232, 1.50727...
# 6   [5.174145221710205, 1.4689007997512817, 1.4518...
# 7   [1.4992742538452148, 1.5470725297927856, 1.539...
# 8   [1.5739414691925049, 1.5447273254394531, 1.745...
# 9   [1.5812599658966064, 1.5477163791656494, 1.536...
# 10  [1.5631039142608643, 1.5398941040039062, 1.536...
# 11  [1.5743471384048462, 1.53955078125, 1.55320811...
# 12  [1.5028350353240967, 1.520816445350647, 1.5024...
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  512 256
# dprout =  0.3
# Epoch 1/3
# 4670/4670 [==============================] - 1775s 380ms/step - loss: 1.0088 - accuracy: 0.7182 - val_loss: 1.5320 - val_accuracy: 0.6116
# Epoch 2/3
# 4670/4670 [==============================] - 1774s 380ms/step - loss: 0.7691 - accuracy: 0.7714 - val_loss: 1.5202 - val_accuracy: 0.6152
# Epoch 3/3
# 4670/4670 [==============================] - 1774s 380ms/step - loss: 0.7321 - accuracy: 0.7781 - val_loss: 1.5152 - val_accuracy: 0.6169
# <class 'pandas.core.frame.DataFrame'>
# Adam 1e-05 512 0.3 [0.7182225584983826, 0.7713578343391418, 0.7781302332878113] [1.008845567703247, 0.7690756320953369, 0.7320558428764343] [0.6116344928741455, 0.6152260899543762, 0.6169335842132568] [1.532021403312683, 1.5201690196990967, 1.515243649482727]
# =========================================================
#    Modele    Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0    Adam  0.00050               1024                512      0.2
# 1    Adam  0.00050               1024                512      0.3
# 2    Adam  0.00050               1024                512      0.4
# 3    Adam  0.00050                512                256      0.2
# 4    Adam  0.00050                512                256      0.3
# 5    Adam  0.00050                512                256      0.4
# 6    Adam  0.00050                128                 64      0.2
# 7    Adam  0.00050                128                 64      0.3
# 8    Adam  0.00050                128                 64      0.4
# 9    Adam  0.00001               1024                512      0.2
# 10   Adam  0.00001               1024                512      0.3
# 11   Adam  0.00001               1024                512      0.4
# 12   Adam  0.00001                512                256      0.2
# 13   Adam  0.00001                512                256      0.3
#
#                                              Accuracy  \
# 0   [0.3269089162349701, 0.4529746472835541, 0.502...
# 1   [0.4716723561286926, 0.528367817401886, 0.5460...
# 2   [0.4972093999385834, 0.5469182729721069, 0.564...
# 3   [0.5579200983047485, 0.5969082713127136, 0.619...
# 4   [0.586401641368866, 0.6285216808319092, 0.6450...
# 5   [0.611911952495575, 0.6499230265617371, 0.6665...
# 6   [0.5834314823150635, 0.5904380679130554, 0.587...
# 7   [0.5840791463851929, 0.5721266865730286, 0.578...
# 8   [0.578956663608551, 0.5851389765739441, 0.5876...
# 9   [0.6067475080490112, 0.6135185956954956, 0.614...
# 10  [0.6125765442848206, 0.61275315284729, 0.61310...
# 11  [0.6144017577171326, 0.6160504221916199, 0.616...
# 12  [0.6137540936470032, 0.6098092198371887, 0.613...
# 13  [0.6116344928741455, 0.6152260899543762, 0.616...
# 14  [0.6163448095321655, 0.6128709316253662, 0.616...
# 15  [0.6092793345451355, 0.6106923818588257, 0.610...
# 16  [0.6114578247070312, 0.6136363744735718, 0.614...
# 17  [0.6124587655067444, 0.6145195364952087, 0.615...
#
#                                              Val_loss
# 0   [99.0074462890625, 81.86626434326172, 188.8943...
# 1   [253.70932006835938, 4.686125755310059, 87.821...
# 2   [1.7382745742797852, 133.24447631835938, 25.40...
# 3   [1.5864728689193726, 5.977613925933838, 1.6857...
# 4   [541.1002197265625, 1.943395972251892, 1.52740...
# 5   [1.553402066230774, 1.503735899925232, 1.50727...
# 6   [5.174145221710205, 1.4689007997512817, 1.4518...
# 7   [1.4992742538452148, 1.5470725297927856, 1.539...
# 8   [1.5739414691925049, 1.5447273254394531, 1.745...
# 9   [1.5812599658966064, 1.5477163791656494, 1.536...
# 10  [1.5631039142608643, 1.5398941040039062, 1.536...
# 11  [1.5743471384048462, 1.53955078125, 1.55320811...
# 12  [1.5028350353240967, 1.520816445350647, 1.5024...
# 13  [1.532021403312683, 1.5201690196990967, 1.5152...
# 14  [1.5336819887161255, 1.5396159887313843, 1.525...
# 15  [1.501166820526123, 1.4782556295394897, 1.4602...
# 16  [1.4771161079406738, 1.4478778839111328, 1.447...
# 17  [1.4824132919311523, 1.4618511199951172, 1.453...

# %%
# recuperation
import numpy as np
import pandas as pd
#import sys
#sys.path.append('../src')
#import Bibli_DataScience_3_2 as ds
chemin_du_fichier =  ds.get_RACINE_SAUVEGARDE() + 'param_grid_'+SUFFIXE_FICHIER+'.csv'
df_reseaux=pd.read_csv(chemin_du_fichier)
df_reseaux.head()
# Out:
#    Unnamed: 0 Modele   Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0           0   Adam  0.0005               1024                512      0.2
# 1           1   Adam  0.0005               1024                512      0.3
# 2           2   Adam  0.0005               1024                512      0.4
# 3           3   Adam  0.0005                512                256      0.2
# 4           4   Adam  0.0005                512                256      0.3
#
#                                                        Accuracy  \
# 0  [0.3269089162349701, 0.4529746472835541, 0.5029244422912598]
# 1   [0.4716723561286926, 0.528367817401886, 0.5460751056671143]
# 2  [0.4972093999385834, 0.5469182729721069, 0.5641705393791199]
# 3  [0.5579200983047485, 0.5969082713127136, 0.6197282671928406]
# 4    [0.586401641368866, 0.6285216808319092, 0.645037829875946]
#
#                                                            Loss  \
# 0  [2.3479812145233154, 1.8700629472732544, 1.6822267770767212]
# 1    [1.84661865234375, 1.5993729829788208, 1.5261061191558838]
# 2  [1.7650712728500366, 1.5388569831848145, 1.4680625200271606]
# 3  [1.5115047693252563, 1.3480229377746582, 1.2574026584625244]
# 4  [1.4107152223587036, 1.2431749105453491, 1.1793632507324219]
#
#                                                     Val_accuracy  \
# 0  [0.4470089375972748, 0.46166980266571045, 0.4775082468986511]
# 1  [0.49617287516593933, 0.5232571959495544, 0.5187234878540039]
# 2     [0.5088318586349487, 0.531029224395752, 0.524375855922699]
# 3   [0.5561116337776184, 0.5432760119438171, 0.5470442771911621]
# 4   [0.5543452501296997, 0.5546396374702454, 0.5676519274711609]
#
#                                                        Val_loss
# 0     [99.0074462890625, 81.86626434326172, 188.89431762695312]
# 1    [253.70932006835938, 4.686125755310059, 87.82160186767578]
# 2  [1.7382745742797852, 133.24447631835938, 25.408248901367188]
# 3   [1.5864728689193726, 5.977613925933838, 1.6857575178146362]
# 4    [541.1002197265625, 1.943395972251892, 1.5274049043655396]

# %%
import json
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 3000)
df_reseaux['Val_acc']=df_reseaux['Val_accuracy'].apply(lambda x :json.loads(x)[2])
df_reseaux[['Modele','Lrate','NbNeurones_Layer1','Dropout','Val_accuracy','Val_acc']]
# Out:
#    Modele    Lrate  NbNeurones_Layer1  Dropout  \
# 0    Adam  0.00050               1024      0.2
# 1    Adam  0.00050               1024      0.3
# 2    Adam  0.00050               1024      0.4
# 3    Adam  0.00050                512      0.2
# 4    Adam  0.00050                512      0.3
# 5    Adam  0.00050                512      0.4
# 6    Adam  0.00050                128      0.2
# 7    Adam  0.00050                128      0.3
# 8    Adam  0.00050                128      0.4
# 9    Adam  0.00001               1024      0.2
# 10   Adam  0.00001               1024      0.3
# 11   Adam  0.00001               1024      0.4
# 12   Adam  0.00001                512      0.2
# 13   Adam  0.00001                512      0.3
# 14   Adam  0.00001                512      0.4
# 15   Adam  0.00001                128      0.2
# 16   Adam  0.00001                128      0.3
# 17   Adam  0.00001                128      0.4
#
#                                                      Val_accuracy   Val_acc
# 0   [0.4470089375972748, 0.46166980266571045, 0.4775082468986511]  0.477508
# 1   [0.49617287516593933, 0.5232571959495544, 0.5187234878540039]  0.518723
# 2      [0.5088318586349487, 0.531029224395752, 0.524375855922699]  0.524376
# 3    [0.5561116337776184, 0.5432760119438171, 0.5470442771911621]  0.547044
# 4    [0.5543452501296997, 0.5546396374702454, 0.5676519274711609]  0.567652
# 5    [0.5584079027175903, 0.5749529004096985, 0.5664743185043335]  0.566474
# 6    [0.5834314823150635, 0.5904380679130554, 0.5870230793952942]  0.587023
# 7    [0.5840791463851929, 0.5721266865730286, 0.5784856081008911]  0.578486
# 8     [0.578956663608551, 0.5851389765739441, 0.5876707434654236]  0.587671
# 9    [0.6067475080490112, 0.6135185956954956, 0.6141073703765869]  0.614107
# 10     [0.6125765442848206, 0.61275315284729, 0.6131064295768738]  0.613106
# 11   [0.6144017577171326, 0.6160504221916199, 0.6162270307540894]  0.616227
# 12   [0.6137540936470032, 0.6098092198371887, 0.6134008169174194]  0.613401
# 13   [0.6116344928741455, 0.6152260899543762, 0.6169335842132568]  0.616934
# 14   [0.6163448095321655, 0.6128709316253662, 0.6168746948242188]  0.616875
# 15   [0.6092793345451355, 0.6106923818588257, 0.6106923818588257]  0.610692
# 16   [0.6114578247070312, 0.6136363744735718, 0.6148139238357544]  0.614814
# 17   [0.6124587655067444, 0.6145195364952087, 0.6158148646354675]  0.615815

# %%
df_reseaux['Val_acc']=df_reseaux['Val_accuracy'].apply(lambda x :json.loads(x)[2])
df_reseaux[['Modele','Lrate','NbNeurones_Layer1','Dropout','Val_accuracy','Val_acc']].nlargest(5,'Val_acc')
# Out:
#    Modele    Lrate  NbNeurones_Layer1  Dropout  \
# 13   Adam  0.00001                512      0.3
# 14   Adam  0.00001                512      0.4
# 11   Adam  0.00001               1024      0.4
# 17   Adam  0.00001                128      0.4
# 16   Adam  0.00001                128      0.3
#
#                                                     Val_accuracy   Val_acc
# 13  [0.6116344928741455, 0.6152260899543762, 0.6169335842132568]  0.616934
# 14  [0.6163448095321655, 0.6128709316253662, 0.6168746948242188]  0.616875
# 11  [0.6144017577171326, 0.6160504221916199, 0.6162270307540894]  0.616227
# 17  [0.6124587655067444, 0.6145195364952087, 0.6158148646354675]  0.615815
# 16  [0.6114578247070312, 0.6136363744735718, 0.6148139238357544]  0.614814

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# Charger le fichier CSV
file_path = chemin_du_fichier  # Remplacez par le chemin réel du fichier
data = pd.read_csv(file_path)

# Convertir les chaînes de liste en listes réelles pour 'Val_accuracy'
data['Val_accuracy'] = data['Val_accuracy'].apply(json.loads)

# Extraire la première valeur de précision de validation pour chaque configuration
data['Val_accuracy_first_epoch'] = data['Val_accuracy'].apply(lambda x: x[0])

# Visualisation
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Lrate', y='Val_accuracy_first_epoch', hue='NbNeurones_Layer1', style='Dropout', s=100)
plt.xscale('log')
plt.xlabel('Taux d\'apprentissage (échelle logarithmique)')
plt.ylabel('Précision de validation (1ère époque)')
plt.title('Précision de validation vs Taux d\'apprentissage pour différents optimiseurs')
plt.legend(title='Paramètres')
plt.grid(True, which="both", ls="--")
plt.show()

# %%
# Charger le fichier CSV
file_path = chemin_du_fichier  # Remplacez par le chemin réel du fichier
data = pd.read_csv(file_path)

# Convertir les chaînes de liste en listes réelles pour 'Val_accuracy'
data['Val_accuracy'] = data['Val_accuracy'].apply(json.loads)

# Extraire la première valeur de précision de validation pour chaque configuration
data['Val_accuracy_first_epoch'] = data['Val_accuracy'].apply(lambda x: x[0])

# Visualisation
sns.relplot (x = "Dropout",
y = "Val_accuracy_first_epoch", style = 'NbNeurones_Layer1',
hue = 'Lrate', col = "NbNeurones_Layer1",
col_wrap = 3, height = 6,
kind = "line", data = data);
plt.grid(True, which="both", ls="--")



plt.show()
# Out:
# C:\Users\shaky\AppData\Local\anaconda3\envs\tfdml_cnn_Rakuten\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shaky\AppData\Local\anaconda3\envs\tfdml_cnn_Rakuten\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shaky\AppData\Local\anaconda3\envs\tfdml_cnn_Rakuten\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shaky\AppData\Local\anaconda3\envs\tfdml_cnn_Rakuten\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shaky\AppData\Local\anaconda3\envs\tfdml_cnn_Rakuten\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shaky\AppData\Local\anaconda3\envs\tfdml_cnn_Rakuten\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data = pd.read_csv(file_path)

# Convertir les chaînes de liste en listes réelles pour 'Val_accuracy'
data['Val_accuracy'] = data['Val_accuracy'].apply(ast.literal_eval)

# Extraire la première valeur de précision de validation pour chaque configuration
data['Val_accuracy_first_epoch'] = data['Val_accuracy'].apply(lambda x: x[0])

# Visualisation
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Dropout', y='Val_accuracy_first_epoch', hue='Modele', style='Modele', s=100)
plt.xscale('linear')
plt.xlabel('Dropout')
plt.ylabel('Précision de validation (1ère époque)')
plt.title('Précision de validation vs Dropout pour différents optimiseurs')
plt.legend(title='Modèle')
plt.grid(True, which="both", ls="--")
plt.show()

# %% [markdown]
# ### a) deuxième type

# %% [markdown]
#             model = Sequential()
#             model.add(base_model) # Ajout du modèle  EfficientNetB1
#             model.add(Flatten())
#             model.add(Dropout(dprout))
#             model.add(Dense(niv1, activation='relu'))
#             model.add(BatchNormalization())
#             model.add(Dense(niv1, activation='relu'))
#             model.add(Dropout(dprout))
#             model.add(Dense(27, activation='softmax'))

# %%
chemin_du_fichier_2 = ds.get_RACINE_SAUVEGARDE() +'param_grid2_'+SUFFIXE_FICHIER+'.csv'
noms_de_colonnes = ['Modele','Lrate', 'NbNeurones_Layer1', 'NbNeurones_Layer2','Dropout','Accuracy','Loss','Val_accuracy','Val_loss']

df_reseaux_2 = pd.DataFrame(columns=noms_de_colonnes)  
  
# Vérifiez si le fichier existe
if os.path.isfile(chemin_du_fichier_2):
    # Le fichier existe, le lire
    df_reseaux_2 = pd.read_csv(chemin_du_fichier_2)
    print("Fichier existant lu avec succès.")
    print(df_reseaux_2['Lrate'].value_counts())
    print(df_reseaux_2['NbNeurones_Layer1'].value_counts())
    print(df_reseaux_2['Dropout'].value_counts())
else:
    # Le fichier n'existe pas, créer un nouveau DataFrame et le sauvegarder
    df_reseaux_2 = pd.DataFrame(columns=noms_de_colonnes)
# Out:
# Fichier existant lu avec succès.
# Lrate
# 0.00001    18
# Name: count, dtype: int64
# NbNeurones_Layer1
# 1024    6
# 512     6
# 256     6
# Name: count, dtype: int64
# Dropout
# 0.2    6
# 0.3    6
# 0.4    6
# Name: count, dtype: int64

# %%
df_reseaux_2.head()
# Out:
#    Unnamed: 0 Modele    Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0           0   Adam  0.00001               1024               1024      0.2
# 1           1    SGD  0.00001               1024               1024      0.2
# 2           2   Adam  0.00001               1024               1024      0.3
# 3           3    SGD  0.00001               1024               1024      0.3
# 4           4   Adam  0.00001               1024               1024      0.4
#
#                                             Accuracy  \
# 0  [0.4143654406070709, 0.5051276087760925, 0.551...
# 1  [0.06799690425395966, 0.12639056146144867, 0.1...
# 2  [0.40415099263191223, 0.4934869110584259, 0.53...
# 3  [0.056750111281871796, 0.1078224927186966, 0.1...
# 4  [0.38612622022628784, 0.46891510486602783, 0.5...
#
#                                                 Loss  \
# 0  [2.1405375003814697, 1.7471896409988403, 1.548...
# 1  [3.632648468017578, 3.3191423416137695, 3.1182...
# 2  [2.205925941467285, 1.798893690109253, 1.60479...
# 3  [3.7082154750823975, 3.4052348136901855, 3.199...
# 4  [2.3098976612091064, 1.9064180850982666, 1.695...
#
#                                         Val_accuracy  \
# 0  [0.2779243588447571, 0.31090590357780457, 0.34...
# 1  [0.15875110030174255, 0.25103655457496643, 0.3...
# 2  [0.307701975107193, 0.35004398226737976, 0.374...
# 3  [0.15353688597679138, 0.24789546430110931, 0.3...
# 4  [0.3215228021144867, 0.36656615138053894, 0.38...
#
#                                             Val_loss
# 0  [2.7276244163513184, 2.5889012813568115, 2.415...
# 1  [3.1085240840911865, 2.802311897277832, 2.5989...
# 2  [2.5918357372283936, 2.442429304122925, 2.3218...
# 3  [3.069866895675659, 2.76082706451416, 2.558560...
# 4  [2.579277515411377, 2.378835678100586, 2.33233...

# %%
df_reseaux_2 = df_reseaux_2.drop('Unnamed: 0', axis=1)

df_reseaux_2[['Modele','Lrate', 'NbNeurones_Layer1', 'Dropout']].head()
# Out:
#   Modele    Lrate  NbNeurones_Layer1  Dropout
# 0   Adam  0.00001               1024      0.2
# 1    SGD  0.00001               1024      0.2
# 2   Adam  0.00001               1024      0.3
# 3    SGD  0.00001               1024      0.3
# 4   Adam  0.00001               1024      0.4

# %%
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Conv2D, MaxPooling2D, BatchNormalization, LeakyReLU, Flatten
from tensorflow.keras.models import Model, Sequential, load_model
#for lrate in [1e-5,5e-6,1e-6]:
for lrate in [1e-5]:    
    for niv1 in [1024,512,256]:   
        for dprout in [0.20,0.30,0.40]:   
            print("=====================  Adam   ============================")
            print("=====================  categorical_crossentropy   ============================")
            print('lrate = ' ,lrate)
            print('niv1 = ' ,niv1)
            print('dprout = ' ,dprout)
            condition = (
                (df_reseaux_2['Modele'] == 'Adam') &
                (df_reseaux_2['Lrate'] == lrate) &
                (df_reseaux_2['NbNeurones_Layer1'] == niv1) &
                (df_reseaux_2['Dropout'] == dprout)
            )
            on_execute = True
            if df_reseaux_2[condition].any().any():
                print("On passe")
                on_execute = False
            model = Sequential()
            model.add(base_model) # Ajout du modèle  EfficientNetB1
            model.add(Flatten())
            model.add(Dropout(dprout))
            model.add(Dense(niv1, activation='relu'))
            model.add(BatchNormalization())
            model.add(Dense(niv1, activation='relu'))
            model.add(Dropout(dprout))
            model.add(Dense(27, activation='softmax'))
            if on_execute :    
                model.compile(optimizer=Adam(learning_rate=lrate), loss='categorical_crossentropy', metrics=['accuracy'])
                training_history = model.fit(dataset_train, epochs=4, validation_data = dataset_test)
                train_acc = training_history.history['accuracy']
                val_acc = training_history.history['val_accuracy']
                tloss = training_history.history['loss']
                tvalloss=training_history.history['val_loss']
                df_reseaux_2.loc[len(df_reseaux_2)] = ['Adam',lrate, niv1,niv1, dprout,train_acc,tloss,val_acc,tvalloss]
                df_reseaux_2.to_csv( chemin_du_fichier_2) 
            print("=====================  SGD   ============================")
            print("=====================  categorical_crossentropy   ============================")
            print('lrate = ' ,lrate)
            print('niv1 = ' ,niv1)
            print('dprout = ' ,dprout)
            on_execute = True
            condition = (
                (df_reseaux_2['Modele'] == 'SGD') &
                (df_reseaux_2['Lrate'] == lrate) &
                (df_reseaux_2['NbNeurones_Layer1'] == niv1) &
                (df_reseaux_2['Dropout'] == dprout)
            )
            if df_reseaux_2[condition].any().any():
                print("On passe")
                on_execute = False
            model = Sequential()
            model.add(base_model) # Ajout du modèle  EfficientNetB1
            model.add(Flatten())
            model.add(Dropout(dprout))
            model.add(Dense(niv1, activation='relu'))
            model.add(BatchNormalization())
            model.add(Dense(niv1, activation='relu'))
            model.add(Dropout(dprout))
            model.add(Dense(27, activation='softmax'))
            if on_execute :  
                model.compile(optimizer=SGD(learning_rate=lrate), loss='categorical_crossentropy', metrics=['accuracy'])
                training_history = model.fit(dataset_train, epochs=4, validation_data = dataset_test)
                train_acc = training_history.history['accuracy']
                val_acc = training_history.history['val_accuracy']
                tloss = training_history.history['loss']
                tvalloss=training_history.history['val_loss']
                df_reseaux_2.loc[len(df_reseaux_2)] = ['SGD',lrate, niv1,niv1, dprout,train_acc,tloss,val_acc,tvalloss]
                df_reseaux_2.to_csv( chemin_du_fichier_2) 
                print("=========================================================")
                print(df_reseaux_2)
df_reseaux_2.to_csv( chemin_du_fichier_2)
# Out:
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  1024
# dprout =  0.2
# On passe
# =====================  SGD   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  1024
# dprout =  0.2
# On passe
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  1024
# dprout =  0.3
# On passe
# =====================  SGD   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  1024
# dprout =  0.3
# On passe
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  1024
# dprout =  0.4
# On passe
# =====================  SGD   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  1024
# dprout =  0.4
# On passe
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  512
# dprout =  0.2
# On passe
# =====================  SGD   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  512
# dprout =  0.2
# On passe
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  512
# dprout =  0.3
# On passe
# =====================  SGD   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  512
# dprout =  0.3
# On passe
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  512
# dprout =  0.4
# On passe
# =====================  SGD   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  512
# dprout =  0.4
# Epoch 1/4
# 2301/2301 [==============================] - 820s 352ms/step - loss: 3.9254 - accuracy: 0.0472 - val_loss: 3.2358 - val_accuracy: 0.1194
# Epoch 2/4
# 2301/2301 [==============================] - 810s 352ms/step - loss: 3.6847 - accuracy: 0.0750 - val_loss: 2.9732 - val_accuracy: 0.1976
# Epoch 3/4
# 2301/2301 [==============================] - 803s 349ms/step - loss: 3.5046 - accuracy: 0.1026 - val_loss: 2.7779 - val_accuracy: 0.2515
# Epoch 4/4
# 2301/2301 [==============================] - 898s 390ms/step - loss: 3.3627 - accuracy: 0.1283 - val_loss: 2.6316 - val_accuracy: 0.2921
# =========================================================
#    Modele    Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0    Adam  0.00001               1024               1024      0.2
# 1     SGD  0.00001               1024               1024      0.2
# 2    Adam  0.00001               1024               1024      0.3
# 3     SGD  0.00001               1024               1024      0.3
# 4    Adam  0.00001               1024               1024      0.4
# 5     SGD  0.00001               1024               1024      0.4
# 6    Adam  0.00001                512                512      0.2
# 7     SGD  0.00001                512                512      0.2
# 8    Adam  0.00001                512                512      0.3
# 9     SGD  0.00001                512                512      0.3
# 10   Adam  0.00001                512                512      0.4
# 11    SGD  0.00001                512                512      0.4
#
#                                              Accuracy  \
# 0   [0.4143654406070709, 0.5051276087760925, 0.551...
# 1   [0.06799690425395966, 0.12639056146144867, 0.1...

# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  256
# dprout =  0.2
# Epoch 1/4
# 2301/2301 [==============================] - 1302s 563ms/step - loss: 2.3358 - accuracy: 0.3646 - val_loss: 2.3655 - val_accuracy: 0.3659
# Epoch 2/4
# 2301/2301 [==============================] - 1661s 722ms/step - loss: 1.9267 - accuracy: 0.4605 - val_loss: 2.1826 - val_accuracy: 0.4107
# Epoch 3/4
# 2301/2301 [==============================] - 1629s 708ms/step - loss: 1.7532 - accuracy: 0.5031 - val_loss: 2.0911 - val_accuracy: 0.4315
# Epoch 4/4
# 2301/2301 [==============================] - 1629s 708ms/step - loss: 1.6284 - accuracy: 0.5331 - val_loss: 1.9904 - val_accuracy: 0.4570
# =====================  SGD   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  256
# dprout =  0.2
# Epoch 1/4
# 2301/2301 [==============================] - 766s 330ms/step - loss: 3.6760 - accuracy: 0.0513 - val_loss: 3.2184 - val_accuracy: 0.1142
# Epoch 2/4
# 2301/2301 [==============================] - 759s 330ms/step - loss: 3.3949 - accuracy: 0.0977 - val_loss: 2.9146 - val_accuracy: 0.1971
# Epoch 3/4
# 2301/2301 [==============================] - 759s 330ms/step - loss: 3.2041 - accuracy: 0.1397 - val_loss: 2.6980 - val_accuracy: 0.2618
# Epoch 4/4
# 2301/2301 [==============================] - 759s 330ms/step - loss: 3.0512 - accuracy: 0.1746 - val_loss: 2.5416 - val_accuracy: 0.3105
# =========================================================
#    Modele    Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0    Adam  0.00001               1024               1024      0.2
# 1     SGD  0.00001               1024               1024      0.2
# 2    Adam  0.00001               1024               1024      0.3
# 3     SGD  0.00001               1024               1024      0.3
# 4    Adam  0.00001               1024               1024      0.4
# 5     SGD  0.00001               1024               1024      0.4
# 6    Adam  0.00001                512                512      0.2
# 7     SGD  0.00001                512                512      0.2
# 8    Adam  0.00001                512                512      0.3
# 9     SGD  0.00001                512                512      0.3
# 10   Adam  0.00001                512                512      0.4
# 11    SGD  0.00001                512                512      0.4
# 12   Adam  0.00001                256                256      0.2
# 13    SGD  0.00001                256                256      0.2
#
#                                              Accuracy  \
# 0   [0.4143654406070709, 0.5051276087760925, 0.551...
# 1   [0.06799690425395966, 0.12639056146144867, 0.1...
# 2   [0.40415099263191223, 0.4934869110584259, 0.53...
# 3   [0.056750111281871796, 0.1078224927186966, 0.1...
# 4   [0.38612622022628784, 0.46891510486602783, 0.5...
# 5   [0.05021664872765541, 0.08990640938282013, 0.1...
# 6   [0.42413169145584106, 0.5120278000831604, 0.55...
# 7   [0.06196601316332817, 0.13095447421073914, 0.1...
# 8   [0.403838574886322, 0.49256324768066406, 0.535...
# 9   [0.03359095752239227, 0.03363170847296715, 0.0...
# 10  [0.3775145709514618, 0.46974366903305054, 0.50...
# 11  [0.04717404022812843, 0.07504651695489883, 0.1...
# 12  [0.3646377921104431, 0.4604935944080353, 0.503...
# 13  [0.05128971114754677, 0.09766235202550888, 0.1...
#
#                                                  Loss  \
# 0   [2.1405375003814697, 1.7471896409988403, 1.548...
# 1   [3.632648468017578, 3.3191423416137695, 3.1182...
# 2   [2.205925941467285, 1.798893690109253, 1.60479...
# 3   [3.7082154750823975, 3.4052348136901855, 3.199...
# 4   [2.3098976612091064, 1.9064180850982666, 1.695...
# 5   [3.9461772441864014, 3.6102678775787354, 3.373...
# 6   [2.0982882976531982, 1.7216954231262207, 1.537...
# 7   [3.5839357376098633, 3.2382960319519043, 3.020...
# 8   [2.1963140964508057, 1.800652265548706, 1.6245...
# 9   [3.944746971130371, 3.9110047817230225, 3.8820...
# 10  [2.3149187564849854, 1.8981932401657104, 1.727...
# 11  [3.9253854751586914, 3.6846694946289062, 3.504...
# 12  [2.3357739448547363, 1.9267393350601196, 1.753...
# 13  [3.676025629043579, 3.3949460983276367, 3.2041...
#
#                                          Val_accuracy  \
# 0   [0.2779243588447571, 0.31090590357780457, 0.34...
# 1   [0.15875110030174255, 0.25103655457496643, 0.3...
# 2   [0.307701975107193, 0.35004398226737976, 0.374...
# 3   [0.15353688597679138, 0.24789546430110931, 0.3...
# 4   [0.3215228021144867, 0.36656615138053894, 0.38...
# 5   [0.13349667191505432, 0.22584496438503265, 0.2...
# 6   [0.3348410725593567, 0.38019853830337524, 0.39...
# 7   [0.146500825881958, 0.26014575362205505, 0.328...
# 8   [0.3952758014202118, 0.40802866220474243, 0.43...
# 9   [0.03593416512012482, 0.037190601229667664, 0....
# 10  [0.4401935040950775, 0.44176405668258667, 0.44...
# 11  [0.11942455172538757, 0.1976379007101059, 0.25...
# 12  [0.3659379482269287, 0.4107300043106079, 0.431...
# 13  [0.1142103299498558, 0.197135329246521, 0.2618...
#
#                                              Val_loss
# 0   [2.7276244163513184, 2.5889012813568115, 2.415...
# 1   [3.1085240840911865, 2.802311897277832, 2.5989...
# 2   [2.5918357372283936, 2.442429304122925, 2.3218...
# 3   [3.069866895675659, 2.76082706451416, 2.558560...
# 4   [2.579277515411377, 2.378835678100586, 2.33233...
# 5   [3.1616013050079346, 2.828003406524658, 2.5985...
# 6   [2.422790050506592, 2.2597815990448, 2.2366325...
# 7   [3.066999912261963, 2.7135603427886963, 2.4888...
# 8   [2.2010605335235596, 2.115125894546509, 2.0375...
# 9   [3.58011531829834, 3.5547263622283936, 3.53318...
# 10  [2.0160841941833496, 2.015071153640747, 1.9965...
# 11  [3.235786199569702, 2.973207950592041, 2.77790...
# 12  [2.3655147552490234, 2.1826374530792236, 2.091...
# 13  [3.2184455394744873, 2.914591073989868, 2.6980...
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  256
# dprout =  0.3
# Epoch 1/4
# 2301/2301 [==============================] - 1025s 442ms/step - loss: 2.3968 - accuracy: 0.3547 - val_loss: 2.1020 - val_accuracy: 0.4267
# Epoch 2/4
# 2301/2301 [==============================] - 1010s 439ms/step - loss: 1.9842 - accuracy: 0.4503 - val_loss: 1.9734 - val_accuracy: 0.4585
# Epoch 3/4
# 2301/2301 [==============================] - 1013s 440ms/step - loss: 1.8188 - accuracy: 0.4879 - val_loss: 1.9088 - val_accuracy: 0.4785
# Epoch 4/4
# 2301/2301 [==============================] - 1014s 441ms/step - loss: 1.7029 - accuracy: 0.5152 - val_loss: 1.8737 - val_accuracy: 0.4842
# =====================  SGD   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  256
# dprout =  0.3
# Epoch 1/4
# 2301/2301 [==============================] - 766s 330ms/step - loss: 3.6846 - accuracy: 0.0618 - val_loss: 3.1581 - val_accuracy: 0.1485
# Epoch 2/4
# 2301/2301 [==============================] - 757s 329ms/step - loss: 3.4200 - accuracy: 0.1076 - val_loss: 2.8662 - val_accuracy: 0.2238
# Epoch 3/4
# 2301/2301 [==============================] - 757s 329ms/step - loss: 3.2326 - accuracy: 0.1470 - val_loss: 2.6639 - val_accuracy: 0.2743
# Epoch 4/4
# 2301/2301 [==============================] - 757s 329ms/step - loss: 3.0938 - accuracy: 0.1766 - val_loss: 2.5178 - val_accuracy: 0.3147
# =========================================================
#    Modele    Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0    Adam  0.00001               1024               1024      0.2
# 1     SGD  0.00001               1024               1024      0.2
# 2    Adam  0.00001               1024               1024      0.3
# 3     SGD  0.00001               1024               1024      0.3
# 4    Adam  0.00001               1024               1024      0.4
# 5     SGD  0.00001               1024               1024      0.4
# 6    Adam  0.00001                512                512      0.2
# 7     SGD  0.00001                512                512      0.2
# 8    Adam  0.00001                512                512      0.3
# 9     SGD  0.00001                512                512      0.3
# 10   Adam  0.00001                512                512      0.4
# 11    SGD  0.00001                512                512      0.4
# 12   Adam  0.00001                256                256      0.2
# 13    SGD  0.00001                256                256      0.2
# 14   Adam  0.00001                256                256      0.3
# 15    SGD  0.00001                256                256      0.3
#
#                                              Accuracy  \
# 0   [0.4143654406070709, 0.5051276087760925, 0.551...
# 1   [0.06799690425395966, 0.12639056146144867, 0.1...
# 2   [0.40415099263191223, 0.4934869110584259, 0.53...
# 3   [0.056750111281871796, 0.1078224927186966, 0.1...
# 4   [0.38612622022628784, 0.46891510486602783, 0.5...
# 5   [0.05021664872765541, 0.08990640938282013, 0.1...
# 6   [0.42413169145584106, 0.5120278000831604, 0.55...
# 7   [0.06196601316332817, 0.13095447421073914, 0.1...
# 8   [0.403838574886322, 0.49256324768066406, 0.535...
# 9   [0.03359095752239227, 0.03363170847296715, 0.0...
# 10  [0.3775145709514618, 0.46974366903305054, 0.50...
# 11  [0.04717404022812843, 0.07504651695489883, 0.1...
# 12  [0.3646377921104431, 0.4604935944080353, 0.503...
# 13  [0.05128971114754677, 0.09766235202550888, 0.1...
# 14  [0.3546678125858307, 0.4502791166305542, 0.487...
# 15  [0.06176226586103439, 0.1076459139585495, 0.14...
#
#                                                  Loss  \
# 0   [2.1405375003814697, 1.7471896409988403, 1.548...
# 1   [3.632648468017578, 3.3191423416137695, 3.1182...
# 2   [2.205925941467285, 1.798893690109253, 1.60479...
# 3   [3.7082154750823975, 3.4052348136901855, 3.199...
# 4   [2.3098976612091064, 1.9064180850982666, 1.695...
# 5   [3.9461772441864014, 3.6102678775787354, 3.373...
# 6   [2.0982882976531982, 1.7216954231262207, 1.537...
# 7   [3.5839357376098633, 3.2382960319519043, 3.020...
# 8   [2.1963140964508057, 1.800652265548706, 1.6245...
# 9   [3.944746971130371, 3.9110047817230225, 3.8820...
# 10  [2.3149187564849854, 1.8981932401657104, 1.727...
# 11  [3.9253854751586914, 3.6846694946289062, 3.504...
# 12  [2.3357739448547363, 1.9267393350601196, 1.753...
# 13  [3.676025629043579, 3.3949460983276367, 3.2041...
# 14  [2.396806001663208, 1.9841923713684082, 1.8187...
# 15  [3.6846303939819336, 3.420029401779175, 3.2325...
#
#                                          Val_accuracy  \
# 0   [0.2779243588447571, 0.31090590357780457, 0.34...
# 1   [0.15875110030174255, 0.25103655457496643, 0.3...
# 2   [0.307701975107193, 0.35004398226737976, 0.374...
# 3   [0.15353688597679138, 0.24789546430110931, 0.3...
# 4   [0.3215228021144867, 0.36656615138053894, 0.38...
# 5   [0.13349667191505432, 0.22584496438503265, 0.2...
# 6   [0.3348410725593567, 0.38019853830337524, 0.39...
# 7   [0.146500825881958, 0.26014575362205505, 0.328...
# 8   [0.3952758014202118, 0.40802866220474243, 0.43...
# 9   [0.03593416512012482, 0.037190601229667664, 0....
# 10  [0.4401935040950775, 0.44176405668258667, 0.44...
# 11  [0.11942455172538757, 0.1976379007101059, 0.25...
# 12  [0.3659379482269287, 0.4107300043106079, 0.431...
# 13  [0.1142103299498558, 0.197135329246521, 0.2618...
# 14  [0.4267496168613434, 0.4585375189781189, 0.478...
# 15  [0.1485111266374588, 0.22383466362953186, 0.27...
#
#                                              Val_loss
# 0   [2.7276244163513184, 2.5889012813568115, 2.415...
# 1   [3.1085240840911865, 2.802311897277832, 2.5989...
# 2   [2.5918357372283936, 2.442429304122925, 2.3218...
# 3   [3.069866895675659, 2.76082706451416, 2.558560...
# 4   [2.579277515411377, 2.378835678100586, 2.33233...
# 5   [3.1616013050079346, 2.828003406524658, 2.5985...
# 6   [2.422790050506592, 2.2597815990448, 2.2366325...
# 7   [3.066999912261963, 2.7135603427886963, 2.4888...
# 8   [2.2010605335235596, 2.115125894546509, 2.0375...
# 9   [3.58011531829834, 3.5547263622283936, 3.53318...
# 10  [2.0160841941833496, 2.015071153640747, 1.9965...
# 11  [3.235786199569702, 2.973207950592041, 2.77790...
# 12  [2.3655147552490234, 2.1826374530792236, 2.091...
# 13  [3.2184455394744873, 2.914591073989868, 2.6980...
# 14  [2.101983070373535, 1.9733918905258179, 1.9087...
# 15  [3.1580982208251953, 2.8662219047546387, 2.663...
# =====================  Adam   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  256
# dprout =  0.4
# Epoch 1/4
# 2301/2301 [==============================] - 920s 397ms/step - loss: 2.5007 - accuracy: 0.3350 - val_loss: 1.9748 - val_accuracy: 0.4633
# Epoch 2/4
# 2301/2301 [==============================] - 912s 396ms/step - loss: 2.0704 - accuracy: 0.4315 - val_loss: 1.8913 - val_accuracy: 0.4751
# Epoch 3/4
# 2301/2301 [==============================] - 911s 396ms/step - loss: 1.8972 - accuracy: 0.4703 - val_loss: 1.7882 - val_accuracy: 0.5053
# Epoch 4/4
# 2301/2301 [==============================] - 11415s 5s/step - loss: 1.7867 - accuracy: 0.4925 - val_loss: 1.7689 - val_accuracy: 0.5076
# =====================  SGD   ============================
# =====================  categorical_crossentropy   ============================
# lrate =  1e-05
# niv1 =  256
# dprout =  0.4
# Epoch 1/4
# 2301/2301 [==============================] - 768s 331ms/step - loss: 3.7806 - accuracy: 0.0552 - val_loss: 3.1063 - val_accuracy: 0.1474
# Epoch 2/4
# 2301/2301 [==============================] - 759s 330ms/step - loss: 3.5410 - accuracy: 0.0898 - val_loss: 2.8337 - val_accuracy: 0.2318
# Epoch 3/4
# 2301/2301 [==============================] - 760s 330ms/step - loss: 3.3660 - accuracy: 0.1235 - val_loss: 2.6368 - val_accuracy: 0.2981
# Epoch 4/4
# 2301/2301 [==============================] - 779s 339ms/step - loss: 3.2272 - accuracy: 0.1526 - val_loss: 2.4915 - val_accuracy: 0.3384
# =========================================================
#    Modele    Lrate  NbNeurones_Layer1  NbNeurones_Layer2  Dropout  \
# 0    Adam  0.00001               1024               1024      0.2
# 1     SGD  0.00001               1024               1024      0.2
# 2    Adam  0.00001               1024               1024      0.3
# 3     SGD  0.00001               1024               1024      0.3
# 4    Adam  0.00001               1024               1024      0.4
# 5     SGD  0.00001               1024               1024      0.4
# 6    Adam  0.00001                512                512      0.2
# 7     SGD  0.00001                512                512      0.2
# 8    Adam  0.00001                512                512      0.3
# 9     SGD  0.00001                512                512      0.3
# 10   Adam  0.00001                512                512      0.4
# 11    SGD  0.00001                512                512      0.4
# 12   Adam  0.00001                256                256      0.2
# 13    SGD  0.00001                256                256      0.2
# 14   Adam  0.00001                256                256      0.3
# 15    SGD  0.00001                256                256      0.3
# 16   Adam  0.00001                256                256      0.4
# 17    SGD  0.00001                256                256      0.4
#
#                                              Accuracy  \
# 0   [0.4143654406070709, 0.5051276087760925, 0.551...
# 1   [0.06799690425395966, 0.12639056146144867, 0.1...
# 2   [0.40415099263191223, 0.4934869110584259, 0.53...
# 3   [0.056750111281871796, 0.1078224927186966, 0.1...
# 4   [0.38612622022628784, 0.46891510486602783, 0.5...
# 5   [0.05021664872765541, 0.08990640938282013, 0.1...
# 6   [0.42413169145584106, 0.5120278000831604, 0.55...
# 7   [0.06196601316332817, 0.13095447421073914, 0.1...
# 8   [0.403838574886322, 0.49256324768066406, 0.535...
# 9   [0.03359095752239227, 0.03363170847296715, 0.0...
# 10  [0.3775145709514618, 0.46974366903305054, 0.50...
# 11  [0.04717404022812843, 0.07504651695489883, 0.1...
# 12  [0.3646377921104431, 0.4604935944080353, 0.503...
# 13  [0.05128971114754677, 0.09766235202550888, 0.1...
# 14  [0.3546678125858307, 0.4502791166305542, 0.487...
# 15  [0.06176226586103439, 0.1076459139585495, 0.14...
# 16  [0.33501309156417847, 0.43146654963493347, 0.4...
# 17  [0.055201638489961624, 0.08975699543952942, 0....
#
#                                                  Loss  \
# 0   [2.1405375003814697, 1.7471896409988403, 1.548...
# 1   [3.632648468017578, 3.3191423416137695, 3.1182...
# 2   [2.205925941467285, 1.798893690109253, 1.60479...
# 3   [3.7082154750823975, 3.4052348136901855, 3.199...
# 4   [2.3098976612091064, 1.9064180850982666, 1.695...
# 5   [3.9461772441864014, 3.6102678775787354, 3.373...
# 6   [2.0982882976531982, 1.7216954231262207, 1.537...
# 7   [3.5839357376098633, 3.2382960319519043, 3.020...
# 8   [2.1963140964508057, 1.800652265548706, 1.6245...
# 9   [3.944746971130371, 3.9110047817230225, 3.8820...
# 10  [2.3149187564849854, 1.8981932401657104, 1.727...
# 11  [3.9253854751586914, 3.6846694946289062, 3.504...
# 12  [2.3357739448547363, 1.9267393350601196, 1.753...
# 13  [3.676025629043579, 3.3949460983276367, 3.2041...
# 14  [2.396806001663208, 1.9841923713684082, 1.8187...
# 15  [3.6846303939819336, 3.420029401779175, 3.2325...
# 16  [2.500685214996338, 2.0704314708709717, 1.8972...
# 17  [3.7806012630462646, 3.541003704071045, 3.3659...
#
#                                          Val_accuracy  \
# 0   [0.2779243588447571, 0.31090590357780457, 0.34...
# 1   [0.15875110030174255, 0.25103655457496643, 0.3...
# 2   [0.307701975107193, 0.35004398226737976, 0.374...
# 3   [0.15353688597679138, 0.24789546430110931, 0.3...
# 4   [0.3215228021144867, 0.36656615138053894, 0.38...
# 5   [0.13349667191505432, 0.22584496438503265, 0.2...
# 6   [0.3348410725593567, 0.38019853830337524, 0.39...
# 7   [0.146500825881958, 0.26014575362205505, 0.328...
# 8   [0.3952758014202118, 0.40802866220474243, 0.43...
# 9   [0.03593416512012482, 0.037190601229667664, 0....
# 10  [0.4401935040950775, 0.44176405668258667, 0.44...
# 11  [0.11942455172538757, 0.1976379007101059, 0.25...
# 12  [0.3659379482269287, 0.4107300043106079, 0.431...
# 13  [0.1142103299498558, 0.197135329246521, 0.2618...
# 14  [0.4267496168613434, 0.4585375189781189, 0.478...
# 15  [0.1485111266374588, 0.22383466362953186, 0.27...
# 16  [0.4633120000362396, 0.4750596880912781, 0.505...
# 17  [0.14738032221794128, 0.23181304335594177, 0.2...
#
#                                              Val_loss
# 0   [2.7276244163513184, 2.5889012813568115, 2.415...
# 1   [3.1085240840911865, 2.802311897277832, 2.5989...
# 2   [2.5918357372283936, 2.442429304122925, 2.3218...
# 3   [3.069866895675659, 2.76082706451416, 2.558560...
# 4   [2.579277515411377, 2.378835678100586, 2.33233...
# 5   [3.1616013050079346, 2.828003406524658, 2.5985...
# 6   [2.422790050506592, 2.2597815990448, 2.2366325...
# 7   [3.066999912261963, 2.7135603427886963, 2.4888...
# 8   [2.2010605335235596, 2.115125894546509, 2.0375...
# 9   [3.58011531829834, 3.5547263622283936, 3.53318...
# 10  [2.0160841941833496, 2.015071153640747, 1.9965...
# 11  [3.235786199569702, 2.973207950592041, 2.77790...
# 12  [2.3655147552490234, 2.1826374530792236, 2.091...
# 13  [3.2184455394744873, 2.914591073989868, 2.6980...
# 14  [2.101983070373535, 1.9733918905258179, 1.9087...
# 15  [3.1580982208251953, 2.8662219047546387, 2.663...
# 16  [1.9747567176818848, 1.8912885189056396, 1.788...
# 17  [3.106348991394043, 2.8337173461914062, 2.6367...

# %%
df_reseaux_2['Val_acc']=df_reseaux_2['Val_accuracy'].apply(lambda x : eval(x)[3])
df_reseaux_2[['Modele','Lrate','NbNeurones_Layer1','Dropout','Val_acc']].nlargest(5,'Val_acc')
# Out:
#    Modele    Lrate  NbNeurones_Layer1  Dropout   Val_acc
# 16   Adam  0.00001                256      0.4  0.507601
# 14   Adam  0.00001                256      0.3  0.484232
# 10   Adam  0.00001                512      0.4  0.469154
# 12   Adam  0.00001                256      0.2  0.457030
# 8    Adam  0.00001                512      0.3  0.445282
